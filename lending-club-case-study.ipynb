# %% [markdown]
# # Lending Club Case Study

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# You work for a consumer finance company which specialises in lending various types of loans to urban customers. When the company receives a loan application, the company has to make a decision for loan approval based on the applicant’s profile. Two types of risks are associated with the bank’s decision:
#
# - If the applicant is likely to repay the loan, then not approving the loan results in a loss of business to the company
#
# - If the applicant is not likely to repay the loan, i.e. he/she is likely to default, then approving the loan may lead to a financial loss for the company

# %% [markdown]
# ## Business Objectives

# %% [markdown]
# Use EDA to understand how consumer attributes and loan attributes influence the tendency of default.

# %% [markdown]
# ## Constraints

# %% [markdown]
# When a person applies for a loan, there are two types of decisions that could be taken by the company:
#
# 1. <b>Loan accepted</b>: If the company approves the loan, there are 3 possible scenarios described below:
#
#     - <b>Fully paid</b>: Applicant has fully paid the loan (the principal and the interest rate)
#
#     - <b>Current</b>: Applicant is in the process of paying the instalments, i.e. the tenure of the loan is not yet completed. These candidates are not labelled as 'defaulted'.
#
#     - <b>Charged-off</b>: Applicant has not paid the instalments in due time for a long period of time, i.e. he/she has defaulted on the loan
#
# 2. <b>Loan rejected</b>: The company had rejected the loan (because the candidate does not meet their requirements etc.). Since the loan was rejected, there is no transactional history of those applicants with the company and so this data is not available with the company (and thus in this dataset)

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
# Supress warnings
warnings.filterwarnings('ignore')

# %%
# Import the Load dataset
loan_df = pd.read_csv('loan.csv')

# %%
# Checking the rows and columns in the loan file
loan_df.shape
# Out:
# (39717, 111)

# %%
# General Information about the dataframe
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
loan_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
# 1                NaN            NaN               NaN                  0.0
# 2                NaN            NaN               NaN                  0.0
# 3                NaN            NaN               NaN                  0.0
# 4                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
# 1       0.0             NaN               NaN            NaN
# 2       0.0             NaN               NaN            NaN
# 3       0.0             NaN               NaN            NaN
# 4       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 111 columns]

# %%
loan_df.tail()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 39712  92187      92174       2500         2500           1075.0   36 months
# 39713  90665      90607       8500         8500            875.0   36 months
# 39714  90395      90390       5000         5000           1325.0   36 months
# 39715  90376      89243       5000         5000            650.0   36 months
# 39716  87023      86999       7500         7500            800.0   36 months
#
#       int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 39712    8.07%        78.42     A        A4  ...                NaN
# 39713   10.28%       275.38     C        C1  ...                NaN
# 39714    8.07%       156.84     A        A4  ...                NaN
# 39715    7.43%       155.38     A        A2  ...                NaN
# 39716   13.75%       255.43     E        E2  ...                NaN
#
#       num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 39712                NaN            NaN               NaN
# 39713                NaN            NaN               NaN
# 39714                NaN            NaN               NaN
# 39715                NaN            NaN               NaN
# 39716                NaN            NaN               NaN
#
#       pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# 39712                  NaN       NaN             NaN               NaN
# 39713                  NaN       NaN             NaN               NaN
# 39714                  NaN       NaN             NaN               NaN
# 39715                  NaN       NaN             NaN               NaN
# 39716                  NaN       NaN             NaN               NaN
#
#       total_bc_limit total_il_high_credit_limit
# 39712            NaN                        NaN
# 39713            NaN                        NaN
# 39714            NaN                        NaN
# 39715            NaN                        NaN
# 39716            NaN                        NaN
#
# [5 rows x 111 columns]

# %% [markdown]
# **The data has been read into the dataframe with column names. Now, we can start the data clean up.**

# %% [markdown]
# ### Data Cleanup

# %% [markdown]
# During Data clean up we need to identify the columns that will not add any value to the analysis and remove them from our dataset, like single value across dataset, null values across dataset, high percentage of null values, text or description columns etc.
#
# Also, we need to get rid of the data (row) that is not relevant for the analysis.

# %% [markdown]
# ##### Before starting with analysis on the columns, it would be better to filter the data of interest.

# %%
loan_df.loan_status.value_counts()
# Out:
# loan_status
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: count, dtype: int64

# %% [markdown]
# ###

# %% [markdown]
# As we need to analyse the loan applications that are likely to default or fully paid, the loans that are currently ongoing may not help. So, we need to remove them from dataset.

# %%
# Create a new dataframe from the loan_df by filtering the Fully Paid and Charged Off loan status.

closed_loan_df = loan_df[loan_df.loan_status.isin(['Fully Paid','Charged Off'])]

# %%
# Count of Closed Loan Dataframe

closed_loan_df.shape
# Out:
# (38577, 111)

# %%
# Percent of data/rows dropped from initial file
total_rows_loan_df = loan_df.shape[0]
total_rows_closed_loan_df = closed_loan_df.shape[0]
print(f'Total Data dropped from initial file: {round((total_rows_loan_df - total_rows_closed_loan_df)*100 /total_rows_loan_df, 2)}')
# Out:
# Total Data dropped from initial file: 2.87

# %%
# Check the columns with null value count
closed_loan_df.isnull().sum() *100/total_rows_closed_loan_df
# Out:
# id                              0.000000
# member_id                       0.000000
# loan_amnt                       0.000000
# funded_amnt                     0.000000
# funded_amnt_inv                 0.000000
#                                  ...
# tax_liens                       0.101097
# tot_hi_cred_lim               100.000000
# total_bal_ex_mort             100.000000
# total_bc_limit                100.000000
# total_il_high_credit_limit    100.000000
# Length: 111, dtype: float64

# %% [markdown]
#
# ###### It appears that few columns have 100% data as null. We can drop the columns.

# %%
closed_loan_df.dropna(axis = 1, how='all', inplace = True)

# %%
closed_loan_df.shape
# Out:
# (38577, 56)

# %%
(closed_loan_df.isnull().sum() *100/total_rows_closed_loan_df).sort_values()
# Out:
# id                             0.000000
# earliest_cr_line               0.000000
# open_acc                       0.000000
# pub_rec                        0.000000
# revol_bal                      0.000000
# total_acc                      0.000000
# initial_list_status            0.000000
# out_prncp                      0.000000
# out_prncp_inv                  0.000000
# total_pymnt                    0.000000
# delinq_2yrs                    0.000000
# total_pymnt_inv                0.000000
# total_rec_int                  0.000000
# total_rec_late_fee             0.000000
# recoveries                     0.000000
# collection_recovery_fee        0.000000
# last_pymnt_amnt                0.000000
# policy_code                    0.000000
# application_type               0.000000
# acc_now_delinq                 0.000000
# delinq_amnt                    0.000000
# total_rec_prncp                0.000000
# dti                            0.000000
# inq_last_6mths                 0.000000
# zip_code                       0.000000
# grade                          0.000000
# sub_grade                      0.000000
# term                           0.000000
# addr_state                     0.000000
# home_ownership                 0.000000
# annual_inc                     0.000000
# verification_status            0.000000
# issue_d                        0.000000
# installment                    0.000000
# loan_status                    0.000000
# pymnt_plan                     0.000000
# url                            0.000000
# funded_amnt_inv                0.000000
# funded_amnt                    0.000000
# loan_amnt                      0.000000
# member_id                      0.000000
# purpose                        0.000000
# int_rate                       0.000000
# last_credit_pull_d             0.005184
# title                          0.028514
# tax_liens                      0.101097
# revol_util                     0.129611
# collections_12_mths_ex_med     0.145164
# chargeoff_within_12_mths       0.145164
# last_pymnt_d                   0.184047
# pub_rec_bankruptcies           1.806776
# emp_length                     2.677761
# emp_title                      6.185033
# desc                          32.477901
# mths_since_last_delinq        64.559193
# mths_since_last_record        92.897322
# dtype: float64

# %% [markdown]
# The dataset contains two columns with high null percentage:
#
#     - mths_since_last_record
#     - mths_since_last_delinq
#
# Also, the 'desc' column has 32% Null values and as per column definition, it is the "Loan description provided by the borrower". So, it will not add value to analysis.
#
# These columns can be dropped.

# %%
#drop the three columns with high null value percentage from the datafame.
closed_loan_df.drop(columns = ['mths_since_last_record', 'mths_since_last_delinq', 'desc'], inplace = True)

# %%
closed_loan_df.shape
# Out:
# (38577, 53)

# %% [markdown]
# The columns contain a unique value will not add value to the analysis. The columns can be identified and removed from the dataset.

# %%
# Identify the columns and the number of unique values they hold.

closed_loan_df.nunique().sort_values()
# Out:
# tax_liens                         1
# initial_list_status               1
# out_prncp                         1
# out_prncp_inv                     1
# collections_12_mths_ex_med        1
# policy_code                       1
# pymnt_plan                        1
# application_type                  1
# acc_now_delinq                    1
# chargeoff_within_12_mths          1
# delinq_amnt                       1
# loan_status                       2
# term                              2
# verification_status               3
# pub_rec_bankruptcies              3
# home_ownership                    5
# pub_rec                           5
# grade                             7
# inq_last_6mths                    9
# delinq_2yrs                      11
# emp_length                       11
# purpose                          14
# sub_grade                        35
# open_acc                         40
# addr_state                       50
# issue_d                          55
# total_acc                        82
# last_pymnt_d                    101
# last_credit_pull_d              106
# int_rate                        370
# earliest_cr_line                524
# zip_code                        822
# loan_amnt                       870
# funded_amnt                    1019
# revol_util                     1088
# total_rec_late_fee             1320
# collection_recovery_fee        2616
# dti                            2853
# recoveries                     4040
# annual_inc                     5215
# total_rec_prncp                6841
# funded_amnt_inv                8050
# installment                   15022
# title                         19297
# revol_bal                     21275
# emp_title                     28027
# total_rec_int                 34025
# last_pymnt_amnt               34418
# total_pymnt_inv               36387
# total_pymnt                   36714
# member_id                     38577
# url                           38577
# id                            38577
# dtype: int64

# %% [markdown]
# Drop the columns where the value is unique across columns i.e. Unique values is 1.

# %%
# Get the list of columns where the unique values exactly 1.
columns_with_single_unique_values = closed_loan_df.columns[closed_loan_df.apply(lambda x: x.nunique() == 1)]
columns_with_single_unique_values
# Out:
# Index(['pymnt_plan', 'initial_list_status', 'out_prncp', 'out_prncp_inv',
#        'collections_12_mths_ex_med', 'policy_code', 'application_type',
#        'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt',
#        'tax_liens'],
#       dtype='object')

# %%
# drop the columns from the dataframe
closed_loan_df.drop(columns = columns_with_single_unique_values, inplace = True)

# %%
closed_loan_df.shape
# Out:
# (38577, 42)

# %%
#check the unique values again to verify the columns
closed_loan_df.nunique().sort_values()
# Out:
# loan_status                    2
# term                           2
# pub_rec_bankruptcies           3
# verification_status            3
# pub_rec                        5
# home_ownership                 5
# grade                          7
# inq_last_6mths                 9
# delinq_2yrs                   11
# emp_length                    11
# purpose                       14
# sub_grade                     35
# open_acc                      40
# addr_state                    50
# issue_d                       55
# total_acc                     82
# last_pymnt_d                 101
# last_credit_pull_d           106
# int_rate                     370
# earliest_cr_line             524
# zip_code                     822
# loan_amnt                    870
# funded_amnt                 1019
# revol_util                  1088
# total_rec_late_fee          1320
# collection_recovery_fee     2616
# dti                         2853
# recoveries                  4040
# annual_inc                  5215
# total_rec_prncp             6841
# funded_amnt_inv             8050
# installment                15022
# title                      19297
# revol_bal                  21275
# emp_title                  28027
# total_rec_int              34025
# last_pymnt_amnt            34418
# total_pymnt_inv            36387
# total_pymnt                36714
# url                        38577
# member_id                  38577
# id                         38577
# dtype: int64

# %% [markdown]
# There are three columns which have unique values for each row of data. Also, these columns have below definition suggesting these values are assinged at the time of application:
#     <ol> id: A unique LC assigned ID for the loan listing.</ol>
#     <ol> member_id: A unique LC assigned Id for the borrower member.</ol>
#     <ol> url: URL for the LC page with listing data.</ol>
#
# These do not appear to provide us any insight for the loan application. So, these columns can also be dropped.

# %%
# drop the three columns from the dataframe
closed_loan_df.drop(columns = ['id', 'member_id', 'url'], inplace = True)

# %%
closed_loan_df.shape
# Out:
# (38577, 39)

# %%
closed_loan_df.nunique().sort_values()
# Out:
# loan_status                    2
# term                           2
# pub_rec_bankruptcies           3
# verification_status            3
# pub_rec                        5
# home_ownership                 5
# grade                          7
# inq_last_6mths                 9
# emp_length                    11
# delinq_2yrs                   11
# purpose                       14
# sub_grade                     35
# open_acc                      40
# addr_state                    50
# issue_d                       55
# total_acc                     82
# last_pymnt_d                 101
# last_credit_pull_d           106
# int_rate                     370
# earliest_cr_line             524
# zip_code                     822
# loan_amnt                    870
# funded_amnt                 1019
# revol_util                  1088
# total_rec_late_fee          1320
# collection_recovery_fee     2616
# dti                         2853
# recoveries                  4040
# annual_inc                  5215
# total_rec_prncp             6841
# funded_amnt_inv             8050
# installment                15022
# title                      19297
# revol_bal                  21275
# emp_title                  28027
# total_rec_int              34025
# last_pymnt_amnt            34418
# total_pymnt_inv            36387
# total_pymnt                36714
# dtype: int64

# %% [markdown]
# Looking at the above data, it appears that there are text columns like emp_title and title that may not have any significance on our analysis. The column needs to be evaluated separately.

# %%
closed_loan_df.title.value_counts().index.tolist()
# Out:
# ['Debt Consolidation',
#  'Debt Consolidation Loan',
#  'Personal Loan',
#  'Consolidation',
#  'debt consolidation',
#  'Credit Card Consolidation',
#  'Home Improvement',
#  'Debt consolidation',
#  'Small Business Loan',
#  'Credit Card Loan',
#  'Personal',
#  'Consolidation Loan',
#  'Home Improvement Loan',
#  'personal loan',
#  'personal',
#  'Loan',
#  'Wedding Loan',
#  'Car Loan',
#  'consolidation',
#  'Other Loan',
#  'Credit Card Payoff',
#  'Wedding',
#  'Credit Card Refinance',
#  'Major Purchase Loan',
#  'Consolidate',
#  'Medical',
#  'Credit Card',
#  'home improvement',
#  'Credit Cards',
#  'My Loan',
#  'Debt',
#  'loan',
#  'Business Loan',
#  'Freedom',
#  'Moving Loan',
#  'Personal loan',
#  'consolidate',
#  'debt_consolidation',
#  'Motorcycle',
#  'Debt Consolidation ',
#  'Debt Loan',
#  'Credit Card Debt Consolidation',
#  'Engagement Ring',
#  'Home improvement',
#  'Medical Loan',
#  'Major Purchase',
#  'Consolidate Debt',
#  'credit card consolidation',
#  'debt',
#  'DEBT CONSOLIDATION',
#  'Moving',
#  'Vacation',
#  'debt consolidation loan',
#  'Other',
#  'CC Consolidation',
#  'Credit Card Debt',
#  'Wedding Expenses',
#  'Credit Consolidation',
#  'my loan',
#  'freedom',
#  'Credit Card Consolidation Loan',
#  'Loan 1',
#  'payoff',
#  'Debt Free',
#  'Debt consolidation loan',
#  'Refinance',
#  'consolidation loan',
#  'Bill Consolidation',
#  'Payoff',
#  'Home Improvements',
#  'Small Business',
#  'Credit card consolidation',
#  'Motorcycle Loan',
#  'Pool Loan',
#  'Auto Loan',
#  'Vacation Loan',
#  'Pool',
#  'House Loan',
#  'Consolidation loan',
#  'credit cards',
#  'Debt Payoff',
#  'Home',
#  'Loan Consolidation',
#  'motorcycle',
#  'wedding',
#  'Credit Card Refi',
#  'vacation',
#  'CC Payoff',
#  'Car',
#  'Consolidate debt',
#  'credit card',
#  'Credit Card Refinancing',
#  'Lending Club Loan',
#  'Business',
#  'My loan',
#  'debt loan',
#  'Pay off credit cards',
#  'car loan',
#  'Car loan',
#  'Bills',
#  'CC Refinance',
#  'Lending Club',
#  'car',
#  'credit card refinance',
#  'medical',
#  'Consolidate Credit Card Debt',
#  'major purchase',
#  'pay off credit cards',
#  'Debt Consolodation',
#  'Boat Loan',
#  'credit card payoff',
#  'debt free',
#  'wedding loan',
#  'Home Loan',
#  'Credit card refinance',
#  'Debt Consolidation loan',
#  'CC Loan',
#  'Pay Off',
#  'Medical Expenses',
#  'Student Loan',
#  'bills',
#  'Moving Expenses',
#  'Loan1',
#  'Get out of debt',
#  'get out of debt',
#  'consolidate debt',
#  'Swimming Pool',
#  'Auto',
#  'Credit Card Pay Off',
#  'Fresh Start',
#  'pay off',
#  'Freedom Loan',
#  'Pay Off Credit Cards',
#  'home',
#  'Pay off Credit Cards',
#  'Debt Consolidation loan ',
#  'Credit Card Refinance Loan',
#  'Small Business loan',
#  'PERSONAL LOAN',
#  'Credit Card consolidation',
#  'Consolidating Debt',
#  'credit card loan',
#  'Credit cards',
#  'Pay off debt',
#  'business loan',
#  'Debit Consolidation',
#  'pool',
#  'CC Refi',
#  'loan 1',
#  'Credit Card Payoff Loan',
#  'debt consolidation ',
#  'Consolidation ',
#  'Credit card payoff',
#  'Kitchen Remodel',
#  'Roof',
#  'boat',
#  'Pay off',
#  'My Personal Loan',
#  'home improvements',
#  'Debt Reduction',
#  'House',
#  'Consolidate Credit Cards',
#  'bill consolidation',
#  'Debt Consolidation 2011',
#  'Taxes',
#  'Debt Consolidate',
#  'Debt consolidation loan ',
#  'Debt Relief',
#  'HOME IMPROVEMENT',
#  'moving loan',
#  'credit consolidation',
#  'Paying off credit cards',
#  'Motorcycle loan',
#  'Car Repair',
#  'LOAN',
#  'Personal Loan ',
#  'refinance',
#  'New Start',
#  'Debt consolidation ',
#  'CONSOLIDATION',
#  'vacation loan',
#  'Debt payoff',
#  'Financial Freedom',
#  'CC',
#  'Loan 2',
#  'Card Consolidation',
#  'Boat',
#  'Debt ',
#  'Relocation Loan',
#  'Pay off Debt',
#  'debt relief',
#  'PERSONAL',
#  'Personal ',
#  'Ring',
#  'pool loan',
#  'home improvement loan',
#  'Truck',
#  'Credit Card loan',
#  'moving',
#  'motorcycle loan',
#  'CC Debt',
#  'Refinancing',
#  'Consolidating Credit Card Debt',
#  'credit_card',
#  'auto loan',
#  'Business Expansion',
#  'auto',
#  'Pool loan',
#  'Dept Consolidation',
#  'Debt loan',
#  'Payoff Credit Cards',
#  'Home improvement loan',
#  'Debt Consol',
#  'credit card refinance loan',
#  'Credit Card payoff',
#  'Business loan',
#  'New Roof',
#  'Investment',
#  'Credit Refinance',
#  'Major purchase',
#  'Help',
#  'Wedding Fund',
#  'Purchase',
#  'Loan consolidation',
#  'Bike',
#  'Consolidate Bills',
#  'lending club loan',
#  'Credit Card Elimination',
#  'Truck Loan',
#  'credit',
#  '2010',
#  'truck',
#  'swimming pool',
#  'Pay off credit card',
#  'help',
#  'Home Repairs',
#  'Wedding ',
#  'LendingClub Loan',
#  'Working Capital',
#  'Small_Business Loan',
#  'Medical Bills',
#  'Wedding loan',
#  'credit card debt',
#  'Consolidate credit card debt',
#  'credit card pay off',
#  'medical expenses',
#  'business',
#  'Home loan',
#  'Relocation',
#  'PAYOFF',
#  'Credit card loan',
#  'DEBT FREE',
#  'No more credit cards',
#  'Credit Debt Consolidation',
#  'loan1',
#  'DebtConsolidation',
#  'Remodel',
#  'Tax Loan',
#  'Bill consolidation',
#  'personal ',
#  'pay bills',
#  'Refinance Loan',
#  'Credit Card Repayment',
#  'Discover',
#  'Consolidated',
#  'Medical loan',
#  'Home_Improvement Loan',
#  'New Loan',
#  'debt payoff',
#  'Education',
#  'ATV',
#  'Surgery',
#  'house',
#  'other',
#  'My Debt Consolidation Loan',
#  'Debt Freedom',
#  'out of debt',
#  'Pay Off Debt',
#  'money',
#  'CONSOLIDATE',
#  'CREDIT CARD CONSOLIDATION',
#  'Debt Consolidation Loan ',
#  'Bill Pay',
#  'Starting Over',
#  'discover',
#  'bike',
#  'Credit card',
#  'Consolodation',
#  'Debt consol',
#  'Debt Con',
#  'Cards',
#  'bill pay',
#  'medical loan',
#  'Get out of Debt',
#  'Pay off credit card debt',
#  'credit_card Loan',
#  'debt_consolidation loan',
#  'Home Down Payment',
#  'Credit card debt consolidation',
#  'car repair',
#  'Home Improvement ',
#  'Card Refinance',
#  'Family',
#  'LC Loan',
#  'MY LOAN',
#  'Credit Card Consolidation ',
#  'Payoff Loan',
#  'Home Improvement loan',
#  'CREDIT CARD PAYOFF',
#  'Debts',
#  '2011 Loan',
#  'Emergency',
#  'Credit Card Payoffs',
#  'Landscaping',
#  'Debt Cons',
#  'pay off debt',
#  'credit loan',
#  'ATV Loan',
#  'CC payoff',
#  'BILLS',
#  'Home Improvment',
#  'Consolidating credit card debt',
#  'Consolidation Loan ',
#  'Pay Bills',
#  'CC loan',
#  'Engagement',
#  'Pay It Off',
#  'Debt Consolidation 1',
#  'Credit',
#  'Credit card pay off',
#  'Debt Cosolidation',
#  'School',
#  'home loan',
#  'Debt Consilidation',
#  'Pay Off Credit Card',
#  'Paying off my credit cards',
#  'FREEDOM',
#  'Home Improvement Project',
#  'Truck loan',
#  'Back on Track',
#  'Jeep',
#  'Paying off Credit Cards',
#  'CREDIT CARD DEBT',
#  'Credit Card Debt Consolidation Loan',
#  'wedding expenses',
#  'Credit Debt',
#  'pay off credit card',
#  'pay off bills',
#  'Refi',
#  'Wedding Expense',
#  'Engagement Ring Loan',
#  'RV',
#  'Debt Payment',
#  'Debt relief',
#  'cards',
#  'Paying off debt',
#  'Debt Repayment',
#  'Debt free',
#  'Credit Card Payment',
#  'Debt Help',
#  'Pay off bills',
#  'Furniture',
#  'consolidate bills',
#  'Credit Loan',
#  'purchase',
#  'consolidation ',
#  'My Debt Consolidation',
#  'DC',
#  'Legal Fees',
#  'Kitchen remodel',
#  'Debt reduction',
#  'Auto Repair',
#  'relief',
#  'freedom loan',
#  'Payoff Debt',
#  'Car payoff',
#  'new roof',
#  'Motorcycle Purchase',
#  'American Express',
#  'Wedding Ring',
#  'life saver',
#  'Garage',
#  'No more debt',
#  'Consolidate Debts',
#  'Down Payment',
#  'Pay Down Debt',
#  'New Beginning',
#  'Home improvements',
#  'camper',
#  'personal loan ',
#  'credit refinance',
#  'debt consol',
#  'Credit card consolidation loan',
#  'New Life',
#  'Credit Payoff',
#  'Credit Consolidation Loan',
#  'Credit Card Payoff loan',
#  'Equipment Loan',
#  'CONSOLIDATION LOAN',
#  'Debt Refinance',
#  'No More Credit Cards',
#  'Payback',
#  'dept consolidation',
#  'Pay off Credit Card',
#  'Used Car Loan',
#  'Refinancing Credit Card',
#  'Debt consolidation Loan',
#  'Car Financing',
#  'Home improvement project',
#  'Medical Expense',
#  ' Debt Consolidation',
#  'Other loan',
#  'Credit Card refinance',
#  'Roof Repair',
#  'Expenses',
#  'HELP',
#  'Get Out of Debt',
#  'First Loan',
#  'Auto Repair Loan',
#  'Engagement ring',
#  'Bathroom Remodel',
#  'Our Wedding',
#  'lending club',
#  'Relief',
#  'Auto loan',
#  'debt ',
#  'Refinance Credit Card',
#  'Improvement',
#  'Consolidate credit cards',
#  'CC consolidation',
#  'Money',
#  'Moving expenses',
#  'Amex',
#  'CC Debt Consolidation',
#  'Personal Debt Consolidation',
#  'Wedding expenses',
#  'refi',
#  'Renewable Energy',
#  'MyLoan',
#  'improvement',
#  'RV Loan',
#  'Swimming Pool Loan',
#  'mine',
#  'School Loan',
#  'Consolidation 2011',
#  'Lending Loan',
#  'Car Repairs',
#  'DC Loan',
#  'Credit Card debt',
#  'Adoption Loan',
#  'myloan',
#  'Consol',
#  'LendingClubLoan',
#  'Debt consolidate',
#  'My personal loan',
#  'pay it off',
#  'Credit Cards Consolidation',
#  'cc consolidation',
#  'Debt Pay Off',
#  'Dental',
#  'Bill payoff',
#  'Credit Card Payments',
#  'Smart Loan',
#  'Excellent Credit',
#  'major_purchase',
#  'New Kitchen',
#  'fresh start',
#  'Debt pay off',
#  'debt consilidation',
#  'Business Growth',
#  'Basement',
#  '2011 Debt Consolidation',
#  'DEBT CONSOLIDATION LOAN',
#  'taxes',
#  'First',
#  'home improvment',
#  'Basement Remodel',
#  'Debt consolodation',
#  'dental',
#  'Consolidate Loan',
#  'Windows',
#  '2011 Consolidation',
#  'Capital One Payoff',
#  'Credit Card ',
#  'Bye Bye Credit Cards',
#  'Credit Card Relief',
#  'Consolidating Credit Cards',
#  'roof',
#  'Debt Elimination',
#  'new start',
#  'LendingClub',
#  'Cash',
#  'debt consolodation',
#  'truck loan',
#  'Consolidating credit cards',
#  'Business Purchase',
#  'small_business',
#  'Debt Removal',
#  'Eliminate Debt',
#  'Unexpected Expenses',
#  'Consolidating debt',
#  'Eliminate Credit Card Debt',
#  'Family Loan',
#  'Fresh Start Loan',
#  'card consolidation',
#  'Debt Free!',
#  'A New Beginning',
#  'Home Remodel',
#  'New Beginnings',
#  'Home Project',
#  'MOTORCYCLE',
#  'moving expenses',
#  'Debt Consolidator',
#  "Ryan's Loan",
#  'Education Loan',
#  'Credit consolidation',
#  'Car repairs',
#  'home repairs',
#  'Harley',
#  'Camper',
#  'Jeep Loan',
#  'Emergency Loan',
#  'Chase Payoff',
#  'back on track',
#  'loan consolidation',
#  'pay my bills',
#  'Finishing Basement',
#  'Good Investment',
#  'The Loan',
#  'Conso Loan',
#  'small_business Loan',
#  'card payoff',
#  'Patio',
#  'CAR LOAN',
#  'Getting Married',
#  'New Car',
#  'Credit Pay Off',
#  'School loan',
#  'catch up',
#  'amex',
#  'pay off cards',
#  'credit card consolidation loan',
#  'New Home',
#  'home repair',
#  'expenses',
#  'rv loan',
#  'medical bills',
#  'Consolidation of Credit Cards',
#  'AUTO',
#  'hot tub',
#  'Lower Interest Rate',
#  'bmw',
#  'College Tuition',
#  'Pay off Loan',
#  'Line of Credit',
#  'Debt Consolidation.',
#  'Small Business loan ',
#  'Card Payoff',
#  'Home Improvement loan ',
#  'Credit Card Killer',
#  'High Interest Credit Card Consolidation',
#  'Legal',
#  "Michael's Loan",
#  'Car Refinance',
#  'Car Financing Loan',
#  'Boat Purchase',
#  'Attorney Fees',
#  'Timeshare',
#  'investment',
#  'debt pay off',
#  'debit',
#  'Home repairs',
#  'Plastic Surgery',
#  'Credit Card Consol',
#  'debt consolidate',
#  'Car Loan ',
#  'BofA',
#  'loan 2',
#  'debtconsolidation',
#  'Dental Loan',
#  'credit card consolodation',
#  'Engagment Ring',
#  'Consolidation!',
#  'credit card debt consolidation',
#  'Vehicle',
#  'my personal loan',
#  'Helping Hand',
#  'Debt Consolidaton',
#  'consolidate credit cards',
#  'Personal Consolidation Loan',
#  'Growing Business',
#  'Personal Expenses',
#  'Visa Payoff',
#  'Debt Buster',
#  'mikes loan',
#  'windows',
#  'DEBT',
#  'credit card refi',
#  'Ring Loan',
#  'Final Debt Consolidation',
#  'bill',
#  'Bike Loan',
#  'Unsecured Personal Loan',
#  'Home Repair',
#  'stress relief',
#  'Lending Club Personal Loan',
#  'Down payment',
#  'Consolidation 2010',
#  'Personal debt consolidation',
#  'Credit Card Freedom',
#  'Debt Consolidation 2',
#  'Kitchen Loan',
#  'LOAN1',
#  'home_improvement',
#  'education loan',
#  'bathroom',
#  'PAY OFF',
#  'Mine',
#  'Divorce',
#  'One Payment',
#  '2011',
#  'Credit payoff',
#  'Home Stuff',
#  'December Loan',
#  'debt be gone',
#  'AMEX',
#  'Debt Cons.',
#  'furnace',
#  'Repairs',
#  'credit card refinancing',
#  'Getting out of debt',
#  'Credit Card Consolodation',
#  'the loan',
#  'Backyard',
#  'debt cons.',
#  'Jet Ski',
#  'travel trailer',
#  'Peace of Mind',
#  'one payment',
#  'Green Loan',
#  'CC Consolidation Loan',
#  'cc loan',
#  'Consolidate My Debt',
#  'Credit card debt',
#  'Debt Management',
#  'debtfree',
#  'Clean Slate',
#  'Back Yard',
#  'solar',
#  'school',
#  'Chase',
#  'DEBT PAYOFF',
#  'Debt refinance',
#  'Credit Refi',
#  'Security Deposit',
#  'Consolidation of Debt',
#  'credit payoff',
#  'Wedding Funds',
#  'IVF',
#  'credit debt',
#  'Credit card payment',
#  'Personal Loan 2010',
#  'Florida',
#  'remodel',
#  'Auto Repairs',
#  'home improve',
#  'Debt Free Loan',
#  'Pay off High Interest Credit Card',
#  'Golf Cart',
#  'POOL',
#  'Loan2',
#  'Time Share',
#  'Pay it off',
#  'Used car loan',
#  'Credit Card Paydown',
#  'engagement ring',
#  'Mustang',
#  'Home Improvement/Debt Consolidation',
#  'Home Purchase',
#  'home improvement ',
#  'Investment Opportunity',
#  'Credit card refinancing',
#  'CREDIT CARD PAY OFF',
#  'Moving Loan ',
#  'Lower Interest',
#  'payoff loan',
#  'PersonalLoan',
#  'cash',
#  'Loan 2011',
#  'Debit consolidation',
#  'Startup Loan',
#  'Hope',
#  'Paying off Credit Card Debt',
#  'Reduce Credit Card Debt',
#  'home addition',
#  'Used Car Purchase',
#  'Pay off debts',
#  'Consolidated Loan',
#  'help loan',
#  'LC2',
#  'surgery loan',
#  'Travel',
#  'Credit card refi',
#  'Credit Debt Payoff',
#  'House Projects',
#  'Loan 2010',
#  'Debt Elimination Loan',
#  'Faith',
#  'Consolidating Loan',
#  'debt consolidation loan ',
#  'Relocation Expenses',
#  '3 year plan',
#  'Basement Finishing',
#  'Main',
#  'rv',
#  'House Down Payment',
#  'consol',
#  'Pay Off Loan',
#  'Apartment',
#  'Pay off Credit Card Debt',
#  'Credit refinance',
#  'Pay off my Credit Cards',
#  'Refinance my credit cards',
#  'debt loan ',
#  'Credit Refinance Loan',
#  'Citibank',
#  'New Home Improvements',
#  'Credit Card Pay-Off',
#  'Debt Consolidation Help',
#  'Consolidate bills',
#  'Credit Card Repayment Loan',
#  'PAY OFF DEBT',
#  'Housing',
#  'Debt Consol Loan',
#  'Life Saver',
#  'harley',
#  'Jan-11',
#  'Scooter',
#  'debt free soon',
#  'CC REFI',
#  'Clean up',
#  'Debt Consildation',
#  'New roof',
#  'Credit Card Refinancing Loan',
#  'Cargo Van',
#  'pay credit card',
#  'Relocating',
#  'Property Tax',
#  'education',
#  'Out of Debt',
#  'LC',
#  'home ',
#  'Citi Card',
#  'cc payoff',
#  'operation',
#  'used car loan',
#  'personel',
#  'Nov-11',
#  'Refinance loan',
#  'Medical Consolidation',
#  'Goodbye Debt',
#  'christmas',
#  '15000',
#  'Pay Credit Cards',
#  'Pay off high interest credit card',
#  'debt consolidaton',
#  'Moving Expense',
#  'Home purchase',
#  'payoffs',
#  'Clean Up',
#  'Get out of debt!',
#  'Get out of Debt!',
#  'Becoming Debt Free',
#  'Moving Forward',
#  'New Garage',
#  'debt consoladation',
#  'Kitchen Renovation',
#  'CC refinance',
#  'New Business',
#  'Paying off credit card',
#  'Nov-10',
#  'Freedom From Debt',
#  'savings',
#  'Move',
#  'credit card payment',
#  'Medical Expense Loan',
#  '2010 Debt Consolidation',
#  'investment loan',
#  'Credit Card pay off',
#  'Window Loan',
#  'car repairs',
#  'travel',
#  'Debt Conso',
#  'Debt consolidator',
#  'Business ',
#  'debt free loan',
#  'Credit Card payoff ',
#  'Business Investment',
#  'my debt',
#  "Mel's Loan",
#  'Snowmobile',
#  'Green',
#  'debt gone',
#  'Card Consolidation Loan',
#  'DEBT RELIEF',
#  'home purchase',
#  'spa',
#  'Total Debt Consolidation',
#  'Medical ',
#  'cc',
#  'Room Addition',
#  'Consol Loan',
#  'Travel Trailer',
#  'Engagement Loan',
#  'Dental work',
#  'auto repair',
#  'Eric',
#  'Fence',
#  'Travel Resorts of America',
#  "Matt's Loan",
#  'My Bailout',
#  'homeloan',
#  'debt  consolidation',
#  'Car payment',
#  'free at last',
#  'Vacation loan',
#  'Land Purchase',
#  'Summer 2011',
#  'Home improvement ',
#  'NO MORE DEBT',
#  'Oct-11',
#  'Credit Cards Payoff',
#  "Allen's Debt Consolidation Loan",
#  'Lawyer Fees',
#  'Horse',
#  'Medical Bill Loan',
#  'pay credit cards',
#  'Business Expansion Loan',
#  'Refinancing Credit Cards',
#  'surgery',
#  'Debt Restructure',
#  'CC refi',
#  'Paying off bills',
#  'test',
#  'lower debt',
#  'bill payoff',
#  'save me',
#  'new loan',
#  'Credit Card ReFi',
#  'nice',
#  'credit card ',
#  'Tax payment',
#  'Credit card pay-off',
#  'Credit Card Debt Elimination',
#  'Life',
#  'wedding expense',
#  'Motorcycle Refinance',
#  'honda',
#  'CreditCards',
#  'Pay Off Bills',
#  'Lawyer',
#  'Debit',
#  'Ryan',
#  'One payment',
#  'Refinance high interest credit cards',
#  'Lending Club loan',
#  'Debit Consolidation Loan',
#  'Mazda 3',
#  'tax payment',
#  'Car Payoff',
#  'Responsible Debt Consolidation',
#  'Loan Refinance',
#  'repairs',
#  'Credit Card Reduction',
#  'Investment property',
#  'Vehicle Loan',
#  'Debt Saver',
#  'Dream Wedding',
#  'computer',
#  'all in one',
#  'Paying off Debt',
#  'My Debt',
#  'HVAC',
#  'Matt',
#  'debt freedom',
#  'Pay off High Interest Credit Cards',
#  ' Debt Consolidation Loan',
#  'bike loan',
#  'better rate',
#  'Home repair',
#  'Mercedes',
#  'Merry Christmas',
#  'SCHOOL',
#  'BOAT',
#  'Investment Property',
#  'Get out of debt loan',
#  'Triumph',
#  'DebtConsol',
#  'Credit Card Elimination Loan',
#  'BMW',
#  'fence',
#  'Miscellaneous',
#  'Ducati',
#  'get back on track',
#  'Credit Card Debt Loan',
#  'Debt Payment Loan',
#  'Small business loan',
#  'Roof Replacement',
#  'Taking Control',
#  'Credit loan',
#  'Credit Card refinancing',
#  'Solid Investment',
#  'Pay off CC',
#  "Justin's Loan",
#  '66 Mustang',
#  'Credit card refinance loan',
#  'Condo',
#  'Freedom loan',
#  'Refinance credit card debt',
#  'Out of debt',
#  'Debt be gone',
#  'tax loan',
#  'New Furniture',
#  'House Repairs',
#  'Business Start Up',
#  'Business Equipment',
#  'Property Investment',
#  'Last Loan',
#  'new home',
#  'Repayment',
#  'College Debt',
#  'lower rate',
#  "Mike's Loan",
#  'Empathy Loan',
#  'helping hand',
#  'Credit Card Refi Loan',
#  'bathroom remodel',
#  'Surgery Loan',
#  'Improvements',
#  'Debt Consolidation 101',
#  '2nd loan',
#  'CCdebt',
#  'Credit Card Payoff ',
#  'Payoff loan',
#  'Salvation',
#  'consilidation',
#  'Moving Out Loan',
#  'Lower Interest Rate Loan',
#  'General Purpose',
#  'Loan Request',
#  'Scott',
#  'Expansion',
#  'Auto Refinance',
#  'Signature Loan',
#  'Consolidate credit card debts',
#  'Dedt Consolidation',
#  'HOME IMPROVEMENTS',
#  '2011 loan',
#  'Pay off high interest credit cards',
#  'Remodeling',
#  'pay off ',
#  'HOME REMODEL',
#  'Needed',
#  'CC Payoff Loan',
#  'Medical Procedure',
#  'Lending Tree Loan',
#  'boat loan',
#  'Consolidating High Interest Credit Cards',
#  'Responsible Borrower',
#  'Medical expenses',
#  'Jul-11',
#  'Card payoff',
#  'Refinancing Loan',
#  'Kitchen',
#  'My money',
#  'Engagement Ring ',
#  'Dept consolidation',
#  'Trailer',
#  'LOAN CONSOLIDATION',
#  'Credit Card Cleanup',
#  'Debt Payoff Loan',
#  'CC Debt Consolidation Loan',
#  'Getting Out of Debt',
#  'Lending Club Refinance',
#  'Moving loan',
#  'Pay off cards',
#  'Foundation Repair',
#  'Rent',
#  'Bill Consolidation Loan',
#  'Credit Card PayOff',
#  'Investment Loan',
#  'Debt Refinancing',
#  '12',
#  'Debit ',
#  'Thank You',
#  'PayOff',
#  'Bike loan',
#  'Roof Loan',
#  'Credit card Consolidation',
#  'Debt con',
#  ...]

# %% [markdown]
# The values appears to be random. It can be dropped from the dataframe.
#
# Similar analysis can be performed on the emp_title column.

# %%
closed_loan_df.emp_title.value_counts().index.tolist()
# Out:
# ['US Army',
#  'Bank of America',
#  'IBM',
#  'AT&T',
#  'Kaiser Permanente',
#  'USAF',
#  'Wells Fargo',
#  'UPS',
#  'US Air Force',
#  'Walmart',
#  'United States Air Force',
#  'Lockheed Martin',
#  'Self Employed',
#  'U.S. Army',
#  'Verizon Wireless',
#  'USPS',
#  'US ARMY',
#  'Walgreens',
#  'State of California',
#  'Target',
#  'Self',
#  'Department of Defense',
#  'JP Morgan Chase',
#  'JPMorgan Chase',
#  'Booz Allen Hamilton',
#  'Northrop Grumman',
#  'US Navy',
#  'United States Army',
#  'Verizon',
#  'us army',
#  'Accenture',
#  'Best Buy',
#  'Fidelity Investments',
#  'Comcast',
#  'Home Depot',
#  'Social Security Administration',
#  'US Postal Service',
#  'Wells Fargo Bank',
#  'United States Postal Service',
#  'United Parcel Service',
#  'self',
#  'General Electric',
#  'walmart',
#  'Morgan Stanley',
#  'Sprint',
#  'Citigroup',
#  'Retired',
#  'Merrill Lynch',
#  'American Express',
#  'Columbia University',
#  'Raytheon',
#  'Department of Homeland Security',
#  'PricewaterhouseCoopers',
#  'Department of Veterans Affairs',
#  'General Dynamics',
#  'US Government',
#  'usps',
#  'Internal Revenue Service',
#  'SAIC',
#  'United States Marine Corps',
#  'BAE Systems',
#  'The Home Depot',
#  'ADP',
#  'United States Navy',
#  'Thomson Reuters',
#  'US Bank',
#  'The Boeing Company',
#  'American Airlines',
#  'The Hartford',
#  'Microsoft',
#  'Nordstrom',
#  'CSC',
#  'verizon wireless',
#  'Union Bank',
#  'Wal-Mart',
#  'Citibank',
#  'Self-employed',
#  'Morgan Stanley Smith Barney',
#  'Hewlett Packard',
#  'T-Mobile',
#  'Time Warner Cable',
#  'Department of Justice',
#  'us postal service',
#  'USMC',
#  'walgreens',
#  'Military',
#  'U.S. Air Force',
#  "Macy's",
#  'at&t',
#  'Boeing',
#  'Fiserv',
#  'Whole Foods Market',
#  'Deutsche Bank',
#  'Self-Employed',
#  'Federal Aviation Administration',
#  'United Airlines',
#  'Costco Wholesale',
#  'Army',
#  'Southwest Airlines',
#  'Bank of America Corp.',
#  'General Motors',
#  'bank of america',
#  'Fifth Third Bank',
#  'Pfizer',
#  'Oracle',
#  'NYC Department of Education',
#  'Cisco Systems',
#  'Allstate Insurance',
#  'home depot',
#  'Charter Communications',
#  'Chase',
#  'University of California',
#  'FAA',
#  'US Coast Guard',
#  'Progressive Insurance',
#  'Southern California Edison',
#  'Dell',
#  'Federal Bureau of Prisons',
#  'Target Corporation',
#  'self employed',
#  'Frito Lay',
#  'Ernst & Young',
#  'Apple',
#  'Siemens',
#  'Department of Defense (DOD)',
#  'Ernst & Young LLP',
#  'State of Connecticut',
#  'UPMC',
#  'Chase Bank',
#  'County of San Diego',
#  'Harvard University',
#  'retired',
#  'TD Bank',
#  'Continental Airlines',
#  'Los Angeles Unified School District',
#  'Marriott International',
#  'Costco',
#  'Clark County School District',
#  'Los Angeles County',
#  'U.S. Navy',
#  'wells fargo',
#  'Edward Jones',
#  'NYPD',
#  'Rite Aid',
#  'Bank of New York Mellon',
#  'Charles Schwab',
#  'Credit Suisse',
#  'BNY Mellon',
#  'Bank Of America',
#  'University of Georgia',
#  'State of Michigan',
#  'Citi',
#  'Travelers Insurance',
#  'Verizon Business',
#  'City of Chicago',
#  'KPMG',
#  'SunTrust Bank',
#  'TIAA-CREF',
#  'Honeywell',
#  'Yale University',
#  'Amazon.com',
#  'Texas A&M University',
#  'URS Corporation',
#  'Lowes',
#  'GEICO',
#  'HSBC',
#  'Cardinal Health',
#  'AIG',
#  'T-Mobile USA',
#  'Federal Government',
#  'L-3 Communications',
#  'verizon',
#  'Barclays Capital',
#  'CVS Pharmacy',
#  'State Farm Insurance',
#  'Johnson & Johnson',
#  'Macys',
#  'MetLife',
#  'Capital One',
#  'Starbucks',
#  'Lockheed Martin Corp.',
#  'State of Illinois',
#  'Waste Management',
#  'Microsoft Corporation',
#  'School District of Philadelphia',
#  'ups',
#  'U.S. Postal Service',
#  'Union Pacific Railroad',
#  'FBI',
#  'Sodexo',
#  'Dept of Defense',
#  'GE Healthcare',
#  'Verizon Communications',
#  'University of Florida',
#  'Goldman Sachs',
#  'Trader Joes',
#  'Cargill',
#  'Kroger',
#  'Bechtel',
#  'united parcel service',
#  'ING',
#  'Sears Holdings Corporation',
#  'BB&T',
#  'UBS',
#  'LPL Financial',
#  'Farmers Insurance',
#  'Gap Inc',
#  'Navy',
#  'Northwestern Mutual',
#  'Stanford University',
#  'Sears',
#  'Cox Communications',
#  'State of Texas',
#  'Cornell University',
#  'Boeing Company',
#  'PNC Bank',
#  'wells fargo bank',
#  'Air Force',
#  'Compass Group',
#  'target',
#  'Memorial Sloan-Kettering Cancer Center',
#  'Deloitte',
#  'HP',
#  'University of Pennsylvania',
#  'Chicago Public Schools',
#  'JPMorgan Chase & Co.',
#  'Aetna',
#  'nypd',
#  'Aerotek',
#  'Intel',
#  'Capital One Bank',
#  'CenturyLink',
#  'Cognizant Technology Solutions',
#  'Cablevision',
#  'Rochester Institute of Technology',
#  'cvs pharmacy',
#  'LAUSD',
#  'Oracle Corporation',
#  'American Medical Response',
#  'Boston University',
#  'KPMG LLP',
#  'Northern Trust',
#  'WalMart',
#  'US Army Corps of Engineers',
#  'Computer Sciences Corporation',
#  'San Diego Unified School District',
#  'Schneider Electric',
#  'City of Los Angeles',
#  'United States Coast Guard',
#  'State of Arizona',
#  'Adecco',
#  'URS',
#  'united states postal service',
#  'Sears Holdings',
#  'Parsons Brinckerhoff',
#  'Harris Corporation',
#  'The Walt Disney Company',
#  'IRS',
#  'Office Depot',
#  'ConocoPhillips',
#  'Apple Inc.',
#  '3M',
#  "Trader Joe's",
#  'kaiser permanente',
#  'Schlumberger',
#  'Sovereign Bank',
#  'State of Alabama',
#  'Allstate',
#  'University of Miami',
#  'ATK',
#  'Massachusetts General Hospital',
#  "Lowe's Home Improvement",
#  'EMC Corporation',
#  'NASA',
#  'Penn State University',
#  'University of Chicago',
#  'International Paper',
#  'State of Florida',
#  'self-employed',
#  'wal mart',
#  'Army National Guard',
#  'First Data',
#  'Fedex Express',
#  'Turner Broadcasting',
#  'USDA',
#  'UCSF',
#  'Medco Health Solutions',
#  'Government',
#  'Publix Supermarkets',
#  'Ameriprise Financial',
#  'Autozone',
#  'PricewaterhouseCoopers LLP',
#  'CA Technologies',
#  'Safeway',
#  'Prudential',
#  'Sherwin Williams',
#  'Quest Diagnostics',
#  'Fannie Mae',
#  'RR Donnelley',
#  'Halliburton',
#  'Mayo Clinic',
#  'CVS',
#  'AT and T',
#  'Outback Steakhouse',
#  'Walmart Distribution Center',
#  'AT&T Inc.',
#  'US NAVY',
#  'PwC',
#  'U S Postal Service',
#  'macys',
#  'State of Missouri',
#  'Boston College',
#  'University of Houston',
#  'Network Interpreting Service',
#  'Food Lion',
#  'FedEx Office',
#  'Travelers',
#  'State of Delaware',
#  'ExxonMobil',
#  'UCLA',
#  'MTV Networks',
#  'Commonwealth of Pennsylvania',
#  'UnitedHealth Group',
#  'military',
#  'Citigroup Inc.',
#  'Liberty Mutual',
#  'Chevron',
#  'lowes',
#  'GE',
#  'Electronic Arts',
#  'Jacobs Engineering',
#  'Dell Inc',
#  'Dept. of Homeland Security',
#  'ACS',
#  'City of New York',
#  'comcast',
#  'First American Title',
#  'PepsiCo',
#  'Nationwide Insurance',
#  'costco wholesale',
#  'Madison Square Garden',
#  'Silicon Valley Bank',
#  'Procter & Gamble',
#  'Citizens Bank',
#  'KAISER PERMANENTE',
#  'Franchise Tax Board',
#  'State Street Bank',
#  'Progress Energy',
#  'Department of Veteran Affairs',
#  'Department of Education',
#  'Massage Envy',
#  'Bloomingdales',
#  'Emory University',
#  'Staples',
#  'VERIZON WIRELESS',
#  'Carnival Cruise Lines',
#  'Swedish Medical Center',
#  'Paychex Inc',
#  'GE Capital',
#  'SRA International',
#  'Covidien',
#  'Con Edison',
#  'USAA',
#  'Department of the Army',
#  'Starbucks Coffee Company',
#  'Delta Air Lines',
#  'Dept of Veterans Affairs',
#  'Dow Chemical',
#  'Wells Fargo Advisors',
#  'United Healthcare',
#  'State of Georgia',
#  'University of Virginia',
#  'University of Maryland',
#  'Xerox',
#  'Iron Mountain',
#  'US Postal Service (USPS)',
#  'Paychex',
#  'University of Washington',
#  'American Electric Power',
#  'Halliburton Energy Services',
#  'Transportation Security Administration',
#  'Baltimore County Public Schools',
#  'Alcatel-Lucent',
#  'Cleveland Clinic',
#  'Dept of Homeland Security',
#  'State Street Corporation',
#  "Lowe's",
#  'New York Life',
#  'ICF International',
#  'Time Inc',
#  'Chaffey Joint Union High School District',
#  'New York City Department of Education',
#  'McKesson Corporation',
#  'Invesco',
#  'DOD',
#  'The Vanguard Group',
#  'United Health Group',
#  'McKesson',
#  'Amtrak',
#  'Tufts University',
#  'Wells Fargo Home Mortgage',
#  'Raytheon Company',
#  'Self employed',
#  'County of San Mateo',
#  'Bloomberg LP',
#  'Cigna',
#  'UCSF Medical Center',
#  'Lending Club',
#  'University of Minnesota',
#  'Dish Network',
#  'Convergys',
#  'Wegmans Food Markets',
#  'Caterpillar Inc.',
#  'Colorado State University',
#  'Infor Global Solutions',
#  'HBO',
#  'EMC',
#  'Ford Motor Company',
#  'BBVA Compass',
#  'Bank of the West',
#  'National Park Service',
#  'Commonwealth of Massachusetts',
#  'Applebees',
#  'Contra Costa County',
#  'Wachovia Bank',
#  'John Hancock',
#  'TSA',
#  'Chadbourne & Parke LLP',
#  'New York Presbyterian Hospital',
#  'General Dynamics Information Technology',
#  'Capgemini',
#  'Weill Cornell Medical College',
#  'Red Lobster',
#  'Comerica Bank',
#  'UPS Freight',
#  'Genentech',
#  'Publix',
#  'General Services Administration',
#  'Insight Global',
#  'Webtrends',
#  'Sycuan Casino',
#  'Capital One Financial',
#  'Mercer',
#  'State of Kansas',
#  'The Ohio State University Medical Center',
#  'University of Southern California',
#  'New York City Police Department',
#  'Intel Corporation',
#  'Burger King',
#  'Department of Motor Vehicles',
#  'Best Buy Co. Inc.',
#  'Coldwell Banker',
#  'Enterprise Rent-A-Car',
#  'Cerner Corporation',
#  'CIGNA',
#  'Cintas Corp',
#  'OfficeMax',
#  'General Atomics',
#  'Crossmark',
#  'City of Houston',
#  'EmblemHealth',
#  'San Bernardino County',
#  'Social Security Administration (SSA)',
#  'Denver Health',
#  'The Shaw Group',
#  'US Department of Homeland Security',
#  'County of San Bernardino',
#  'Ingram Micro',
#  'Manpower',
#  'CACI',
#  'John Deere',
#  'Saks Fifth Avenue',
#  'Harris Teeter',
#  'Ohio State University',
#  'New York State Unified Court System',
#  'Hitachi Data Systems',
#  'Centurylink',
#  'Pactiv',
#  'Seagate Technology',
#  'SSA',
#  'Clearwire',
#  'Unilever',
#  'Department of Army',
#  'Loyola University New Orleans',
#  'Jones Walker',
#  'Bed Bath and Beyond',
#  'Colorado Mountain College',
#  'Bed Bath & Beyond',
#  'Klein ISD',
#  'Allstate Insurance Company',
#  'Merrill Corporation',
#  'SNL Financial',
#  'department of homeland security',
#  'University of Colorado',
#  'First Data Corporation',
#  'Tampa General Hospital',
#  'Baptist Health South Florida',
#  'Williams Lea',
#  'enterprise rent a car',
#  'Community Bank',
#  'ATT',
#  'Scottrade',
#  'Geico',
#  'AT&T Mobility',
#  'At&t',
#  'State of Utah',
#  'Allen & Overy LLP',
#  'RBC Wealth Management',
#  'MD Anderson Cancer Center',
#  'Wellpoint',
#  'JPMorgan',
#  'Baylor University Medical Center',
#  'Heritage Bank',
#  'Jacobs Technology',
#  'Procter and Gamble',
#  'Bank of Oklahoma',
#  "Brigham and Women's Hospital",
#  'Georgia Pacific',
#  'Walt Disney World',
#  'University of Pittsburgh',
#  'Deloitte Consulting',
#  'State Street',
#  'PetSmart',
#  'Apria Healthcare',
#  'Walgreen',
#  'Allergan',
#  'Pizza Hut',
#  'UNITED STATES POSTAL SERVICE',
#  'Hewlett-Packard',
#  'Riverside County',
#  'tire kingdom',
#  'Spectrum Health',
#  'Law Firm',
#  'Newark Public Schools',
#  'Prospect Mortgage',
#  'Capital Group Companies',
#  'State of New Jersey',
#  'Apache Corporation',
#  'U.S. Coast Guard',
#  'AECOM',
#  'New York Life Insurance',
#  'KLA-Tencor',
#  'Department of Homeland Security (DHS)',
#  'VA Medical Center',
#  'Fresenius Medical Care',
#  'Securitas Security Services',
#  'Dell Services',
#  'Northwestern University',
#  'Department of State',
#  'Fedex',
#  'CompuCom',
#  'Fidelity National Financial',
#  'Kraft Foods',
#  'Pentegra Retirement Services',
#  'Apple, Inc.',
#  'estes express lines',
#  'Markit',
#  'AARP',
#  'Lennar Corp.',
#  'Experian',
#  'Grant Thornton LLP',
#  'American Red Cross',
#  'Level 3 Communications',
#  'Hewitt Associates',
#  'Florida International University',
#  'Coca-Cola Refreshments',
#  'AT&T ',
#  'New York Life Insurance Company',
#  'Jones Lang LaSalle',
#  'BP',
#  'Pepsico',
#  'Fed Ex',
#  'University of California San Francisco',
#  'TEK Systems',
#  'wal-mart',
#  'Fidelity Information Services',
#  'Carnegie Mellon University',
#  'Barnes and Noble',
#  'Western Digital',
#  'M&T Bank',
#  'Baxter Healthcare',
#  'California Pizza Kitchen',
#  'Global Crossing',
#  'Pitney Bowes',
#  'ARAMARK',
#  'HEB',
#  'University of Rochester',
#  'US Military',
#  'UC Davis',
#  'usmc',
#  'Trinity Health',
#  'Ferguson Enterprises',
#  'Kohls',
#  'cablevision',
#  'Walmart Stores, Inc.',
#  'Philips Healthcare',
#  'Aramark',
#  'Amerigas',
#  'Intel Corp',
#  'Baker Hughes',
#  'Barnes & Noble',
#  'Constellation Energy',
#  'JCPenney',
#  'Spherion',
#  'Bio-Rad Laboratories',
#  'Intuit',
#  'Apple, Inc',
#  'Humana',
#  'Verizon wireless',
#  'DeVry University',
#  'Johnson Controls',
#  'Modis',
#  'U.S Army',
#  'us navy',
#  'JPMorgan Chase Bank',
#  'New York City Transit',
#  'NBC Universal',
#  'City and County of San Francisco',
#  'Kohls Department Stores',
#  'Deloitte Tax LLP',
#  'Department of the Navy',
#  'Duke Energy',
#  'Bureau of Land Management',
#  'Franklin Templeton',
#  'Abbott Laboratories',
#  'Veterans Administration',
#  'Kelly Services',
#  'General Mills',
#  'CarMax',
#  'Columbia University Medical Center',
#  'Gwinnett County Public Schools',
#  "Applebee's",
#  'publix',
#  'Customs and Border Protection',
#  'Hot Topic',
#  'Johns Hopkins University',
#  'Nielsen',
#  'Abercrombie & Fitch',
#  'National Grid',
#  'Lowes Home Improvement',
#  'Aspen Dental',
#  'The Blackstone Group',
#  'Miami-Dade County Public Schools',
#  'The Coca-Cola Company',
#  'Sprint Nextel',
#  'wachovia',
#  'FedEx',
#  'NetSpend',
#  'Montefiore Medical Center',
#  'Citibank, N.A.',
#  'Stifel Nicolaus',
#  'State of Ohio',
#  'City of San Francisco',
#  'state of california',
#  'Rush University Medical Center',
#  'Fort Bend ISD',
#  'GameStop',
#  'Panera Bread',
#  'costco',
#  'The Nielsen Company',
#  'AREVA',
#  'US Department of Veterans Affairs',
#  'Geosyntec Consultants',
#  'state of ohio',
#  'WestEd',
#  'Heald College',
#  'City of Broken Arrow',
#  'national grid',
#  'Bristol-Myers Squibb',
#  'Battelle Memorial Institute',
#  'US Department of Education',
#  'Michigan State University',
#  'NISCAYAH',
#  'Bridgepoint Education',
#  'Darden Restaurants',
#  'Commonwealth of PA',
#  'Ulta',
#  'Lockheed Martin Corporation',
#  'Eastman Kodak',
#  'Teledyne Brown Engineering',
#  'Brown & Brown Insurance',
#  'Freddie Mac',
#  "Dick's Sporting Goods",
#  'Canadian National Railroad',
#  'Aflac',
#  'T. Rowe Price',
#  'American Savings Bank',
#  'The UPS Store',
#  'JPMorganChase',
#  'Avanade',
#  'att',
#  'Publix Super Markets',
#  'Toyota',
#  'Central Intelligence Agency',
#  'chase bank',
#  'U.S. Department of Education',
#  'Kmart',
#  'lockheed martin',
#  'Nike',
#  'US Treasury',
#  'Sage',
#  'Los Angeles Police Department',
#  'Brown Brothers Harriman',
#  'Federal Aviation Administration (FAA)',
#  'Otis Elevator',
#  'The Corcoran Group',
#  'Merced City School District',
#  'Myriad Genetics',
#  'Cartus',
#  'AMC Theatres',
#  'nj transit',
#  'Shaw Industries',
#  'Aurora Diagnostics',
#  'TriNet',
#  'Ernst & Young, LLP',
#  'Maximus',
#  'Hawaii Pacific Health',
#  'sears',
#  'Nestle Purina',
#  'ecolab',
#  'Blackbaud',
#  'Norfolk Southern Railroad',
#  'Banfield',
#  'State of Minnesota',
#  'Sony Computer Entertainment',
#  'Huron Consulting Group',
#  'St Lukes Hospital',
#  'Logan County Schools',
#  'NYSDOT',
#  'allied barton',
#  'DHS/TSA',
#  'National Institutes of Health',
#  'Syracuse University',
#  'Health Net',
#  'Qualcomm, Inc.',
#  'Dept of Army',
#  'BNSF Railway',
#  'Automatic Data Processing',
#  'MillerCoors',
#  'Buffalo Wild Wings',
#  'southwest airlines',
#  'Public Health Institute',
#  'Estes Express Lines',
#  'Exterran',
#  'Virginia Commonwealth University',
#  'Pepsi Beverage Company',
#  'Black Box Network Services',
#  'Google',
#  'army',
#  'Metro PCS',
#  'Robert Half International',
#  'american airlines',
#  'Express Scripts',
#  'dept of veterans affairs',
#  'MGH',
#  'Guardian Life Insurance Company',
#  'shaw group',
#  'Baylor Health Care System',
#  'Edelman',
#  'Jefferson Regional Medical Center',
#  'FEDEX',
#  'The Methodist Hospital',
#  'Penske Truck Leasing',
#  'NYU Medical Center',
#  'US EPA',
#  'PNC',
#  'Wachovia Corp.',
#  'Apollo Group',
#  'Vanguard',
#  'Dillards',
#  'University of Chicago Medical Center',
#  'united states navy',
#  'Inova Health System',
#  'Sentry Insurance',
#  'Time Warner',
#  'Merck',
#  'Post Office',
#  'Cricket Communications',
#  'Acxiom Corporation',
#  'WELLS FARGO',
#  'aramark',
#  'Ingersoll Rand',
#  'Pearson Education',
#  'Roswell Park Cancer Institute',
#  'Pitt County Memorial Hospital',
#  'FCI Constructors, Inc.',
#  'ARCADIS',
#  'CSX TRANSPORTATION',
#  'Quest Software',
#  'ymca',
#  'Wal Mart',
#  'Temple University',
#  'Gilead Sciences',
#  'U.S. Border Patrol',
#  'Oregon State University',
#  'Medtronic',
#  'the home depot',
#  'Rutgers University',
#  'G4S Secure Solutions',
#  'UCSD',
#  'delta airlines',
#  'Siemens Industry Inc',
#  'Att',
#  'Macys Inc',
#  'Polo Ralph Lauren',
#  'Towers Watson',
#  'University of California, Davis',
#  'Northern Trust Company',
#  'Tower Automotive',
#  'Sun Life Financial',
#  'Hospital For Special Surgery',
#  'Mcdonalds',
#  'OMD',
#  'Compucom',
#  'Principal Financial Group',
#  'Fairchild Semiconductor',
#  'USN',
#  'WALMART',
#  'Hyatt',
#  'Ace Hardware Corporation',
#  'Florida Highway Patrol',
#  'Winn-Dixie',
#  'Wipro',
#  'BNSF',
#  'Cal Fire',
#  'Village Transportation',
#  'ABM Industries',
#  'Applied Materials',
#  'AXA Equitable',
#  'The University of Chicago',
#  'Navy Federal Credit Union',
#  'Manhattan Beach Unified School District',
#  'Blockbuster',
#  'Treasure Island',
#  'Symantec',
#  'SourceMedia',
#  'Beckman Coulter',
#  'Siemens Healthcare',
#  'Express Employment Professionals',
#  'Rackspace',
#  'Oracle Corp',
#  'City of Richmond',
#  'Norfolk Southern',
#  'Sara Lee',
#  'McDonalds',
#  'McGladrey',
#  'Michelin North America',
#  'Hormel Foods Corporation',
#  'Law Office',
#  'Sharyland I.S.D.',
#  'Huntington National Bank',
#  'Calpine',
#  'Pensacola Christian College',
#  'Yale New Haven Hospital',
#  'Wal-mart',
#  'eBay',
#  'J.P. Morgan Chase',
#  'Serco Inc',
#  'Catholic Healthcare West',
#  'Hospital for Special Surgery',
#  'Sharp Healthcare',
#  'ITT Corporation',
#  'Mount Sinai Hospital',
#  'Washington University School of Medicine',
#  'Epsilon',
#  'Apex Systems Inc',
#  'Country Financial',
#  'Tulalip Casino',
#  'GM Financial',
#  'Sams Club',
#  'UT Southwestern',
#  'KPMG, LLP',
#  'Yeshiva University',
#  'Keiser University',
#  'Royal Bank of Scotland',
#  'Travelers Insurance Co.',
#  'Ericsson',
#  'Turner Construction',
#  'Hartford Hospital',
#  'U.S.P.S.',
#  'Cambridge Associates',
#  'Millenium Partners',
#  'Advanced Technology Services',
#  'Pricewaterhouse Coopers',
#  'Qwest',
#  'jp morgan chase',
#  'Baltimore County Public Library',
#  'JP Morgan',
#  'Multiband',
#  'UC Berkeley',
#  'Passaic Board of Education',
#  'Sikorsky Aircraft Corporation',
#  'Teksystems',
#  'Cerner',
#  'Teleperformance USA',
#  'Georgetown University',
#  'U.S. Fish & Wildlife Service',
#  'King County',
#  'Flagstar Bank',
#  'Alameda County',
#  'The Boston Consulting Group',
#  'Chartis',
#  'Consol Energy',
#  'TIEN TIEN FOOD CO',
#  'Cengage Learning',
#  'Henry Ford Hospital',
#  'Grand Casino',
#  'Marriott',
#  'BNP Paribas',
#  'Janney Montgomery Scott',
#  'DEPARTMENT OF DEFENSE',
#  'Blue Shield of California',
#  'AGIA',
#  'Colliers International',
#  'ADT Security Services',
#  'Banfield Pet Hospital',
#  'Loyola University Chicago',
#  'HMS Host',
#  'U.S. Department of Agriculture',
#  'Brown University',
#  'Crowe Horwath, LLP',
#  'McKesson Corp',
#  'State of Oregon',
#  'Gap Inc.',
#  '24 Hour Fitness',
#  'Avis Budget Group',
#  'U.S.Postal Service',
#  'PPG Industries',
#  'bed bath and beyond',
#  'Portland Public Schools',
#  'Orange County Public Schools',
#  'Goodwin Procter LLP',
#  'Walden University',
#  'bloomingdales',
#  'The Rockefeller University',
#  'University Hospital',
#  'Miami University',
#  'Pacific Gas and Electric Company',
#  'American Public Media',
#  'goodyear',
#  'Waterbury Hospital',
#  'Juniper Networks',
#  'Walgreens Pharmacy',
#  'Universal Health Services',
#  'Georgia Institute of Technology',
#  'Dept of Justice',
#  'Us Army',
#  'Honeywell International Inc.',
#  'JPMORGAN CHASE',
#  'RBC Bank',
#  'Stop and Shop',
#  'Battelle',
#  'City of Mesa',
#  'Arizona State University',
#  'AllianceBernstein',
#  'Oregon Health & Science University',
#  'Tech Data Corporation',
#  'Us army',
#  'Travelers Insurance Company',
#  'Carroll County Public Schools',
#  'Nestle',
#  'Burlington Coat Factory',
#  'Luxottica Retail',
#  'Fairfax County Public Schools',
#  'Mass General Hospital',
#  'Affinity Marketing Group',
#  'Apple Inc',
#  "O'Reilly Auto Parts",
#  'Torrance Memorial Medical Center',
#  'PC-Doctor, Inc.',
#  'Nestle Waters North America',
#  'Dicks Sporting Goods',
#  'CH2M Hill',
#  'Copart',
#  'NetApp',
#  'Kohler Company',
#  'State Farm',
#  'Doubletree Hotel',
#  'Education Management Corporation',
#  'New York University',
#  'Ohio State University Medical Center',
#  'nyc transit',
#  'Dallas ISD',
#  'United States Department of State',
#  'Genzyme',
#  'FDNY',
#  'Las Vegas Valley Water District',
#  'Memorial Sloan Kettering Cancer Center',
#  'Demand Media',
#  'Nielsen Company',
#  'PG&E',
#  'fedex express',
#  'HP Enterprise Services',
#  'Hewlett-Packard Company',
#  'board of ed',
#  'Assurant',
#  'SPR Industries',
#  'University of California, San Diego',
#  'University of South Carolina',
#  'Fairview Health Services',
#  ...]

# %% [markdown]
# The emp_title also appears to be random values. These two columns can be dropped from dataframe.

# %%
closed_loan_df.drop(columns = ['title', 'emp_title'], inplace = True)

# %%
closed_loan_df.shape
# Out:
# (38577, 37)

# %%
closed_loan_df.nunique().sort_values()
# Out:
# term                           2
# loan_status                    2
# pub_rec_bankruptcies           3
# verification_status            3
# pub_rec                        5
# home_ownership                 5
# grade                          7
# inq_last_6mths                 9
# delinq_2yrs                   11
# emp_length                    11
# purpose                       14
# sub_grade                     35
# open_acc                      40
# addr_state                    50
# issue_d                       55
# total_acc                     82
# last_pymnt_d                 101
# last_credit_pull_d           106
# int_rate                     370
# earliest_cr_line             524
# zip_code                     822
# loan_amnt                    870
# funded_amnt                 1019
# revol_util                  1088
# total_rec_late_fee          1320
# collection_recovery_fee     2616
# dti                         2853
# recoveries                  4040
# annual_inc                  5215
# total_rec_prncp             6841
# funded_amnt_inv             8050
# installment                15022
# revol_bal                  21275
# total_rec_int              34025
# last_pymnt_amnt            34418
# total_pymnt_inv            36387
# total_pymnt                36714
# dtype: int64

# %% [markdown]
# Now, going through the individual columns and their definition, it can be understood that the below column values are available either after the loan application is approved, or it has no signifiance with respect to analysis.
#
# - **delinq_2yrs**: The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years - Post Loan application data
# - **last_pymnt_d**: Last month payment was received - Post Loan application data
# - **last_credit_pull_d**: The most recent month LC pulled credit for this loan - Post Loan application data
# - **total_rec_late_fee**: Late fees received to date - Post Loan application data
# - **collection_recovery_fee**: Post charge off collection fee - Post Loan application data
# - **recoveries**: Post charge off gross recovery - Post Loan application data
# - **total_rec_prncp**: Principal received to date - Post Loan application data
# - **revol_bal**: Total credit revolving balance - Post Loan application data
# - **total_rec_int**: Interest received to date - Post Loan application data
# - **last_pymnt_amnt**: Last total payment amount received - Post Loan application data
# - **total_pymnt_inv**: Payments received to date for portion of total amount funded by investors - Post Loan application data
# - **total_pymnt**: Payments received to date for total amount funded - Post Loan application data
# - **inq_last_6mths**: The number of inquiries in past 6 months (excluding auto and mortgage inquiries) - Post Loan application data
# - **zip_code**: The first 3 numbers of the zip code provided by the borrower in the loan application - has similar significance as the 'addr_state' column
# - **earliest_cr_line**: The month the borrower's earliest reported credit line was opened - No impact on loan repayment

# %%
closed_loan_df.drop(columns = ['delinq_2yrs', 'last_pymnt_d', 'last_credit_pull_d', 'total_rec_late_fee', 'collection_recovery_fee', 'recoveries', 'total_rec_prncp', 'revol_bal', 'total_rec_int', 'last_pymnt_amnt', 'total_pymnt_inv', 'total_pymnt', 'inq_last_6mths', 'zip_code', 'earliest_cr_line'], inplace = True)

# %%
closed_loan_df.shape
# Out:
# (38577, 22)

# %%
closed_loan_df.isnull().sum()
# Out:
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# emp_length              1033
# home_ownership             0
# annual_inc                 0
# verification_status        0
# issue_d                    0
# loan_status                0
# purpose                    0
# addr_state                 0
# dti                        0
# open_acc                   0
# pub_rec                    0
# revol_util                50
# total_acc                  0
# pub_rec_bankruptcies     697
# dtype: int64

# %%
closed_loan_df.emp_length.value_counts()
# Out:
# emp_length
# 10+ years    8488
# < 1 year     4508
# 2 years      4291
# 3 years      4012
# 4 years      3342
# 5 years      3194
# 1 year       3169
# 6 years      2168
# 7 years      1711
# 8 years      1435
# 9 years      1226
# Name: count, dtype: int64

# %%
closed_loan_df.pub_rec_bankruptcies.value_counts()
# Out:
# pub_rec_bankruptcies
# 0.0    36238
# 1.0     1637
# 2.0        5
# Name: count, dtype: int64

# %%
closed_loan_df.nunique().sort_values()
# Out:
# term                        2
# loan_status                 2
# pub_rec_bankruptcies        3
# verification_status         3
# pub_rec                     5
# home_ownership              5
# grade                       7
# emp_length                 11
# purpose                    14
# sub_grade                  35
# open_acc                   40
# addr_state                 50
# issue_d                    55
# total_acc                  82
# int_rate                  370
# loan_amnt                 870
# funded_amnt              1019
# revol_util               1088
# dti                      2853
# annual_inc               5215
# funded_amnt_inv          8050
# installment             15022
# dtype: int64

# %% [markdown]
# Now we have the dataframe with columns that are of our interest. We need to clean up the data for our analysis.

# %% [markdown]
# ### Data Cleanup

# %%
closed_loan_df.emp_length.value_counts().plot.bar()
# Out:
# <Axes: xlabel='emp_length'>

# %%
features_df = closed_loan_df.copy()

# %%
features_df.pub_rec_bankruptcies.unique()
# Out:
# array([ 0.,  1.,  2., nan])

# %%
features_df.emp_length.unique()
# Out:
# array(['10+ years', '< 1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '1 year', '6 years', '2 years', '7 years',
#        nan], dtype=object)

# %%
round((features_df.isnull().sum()*100)/features_df.shape[0],2)
# Out:
# loan_amnt               0.00
# funded_amnt             0.00
# funded_amnt_inv         0.00
# term                    0.00
# int_rate                0.00
# installment             0.00
# grade                   0.00
# sub_grade               0.00
# emp_length              2.68
# home_ownership          0.00
# annual_inc              0.00
# verification_status     0.00
# issue_d                 0.00
# loan_status             0.00
# purpose                 0.00
# addr_state              0.00
# dti                     0.00
# open_acc                0.00
# pub_rec                 0.00
# revol_util              0.13
# total_acc               0.00
# pub_rec_bankruptcies    1.81
# dtype: float64

# %%
total_row_count_before_dropping_na = features_df.shape[0]
total_row_count_before_dropping_na
# Out:
# 38577

# %%
features_df.dropna(axis = 0, how = 'any', inplace=True)

# %%
total_row_count_after_dropping_na = features_df.shape[0]
total_row_count_after_dropping_na
# Out:
# 36800

# %%
round(total_row_count_after_dropping_na*100/total_row_count_before_dropping_na, 2)
# Out:
# 95.39

# %% [markdown]
# Clean up Employee length column data.

# %%
features_df.emp_length.value_counts()
# Out:
# emp_length
# 10+ years    8368
# < 1 year     4329
# 2 years      4202
# 3 years      3947
# 4 years      3290
# 5 years      3157
# 1 year       3071
# 6 years      2133
# 7 years      1686
# 8 years      1408
# 9 years      1209
# Name: count, dtype: int64

# %%
features_df.emp_length = features_df.emp_length.apply(lambda x: 0 if x == '< 1 year' else (10 if x == '10+ years' else str(x).split()[0]))

# %%
features_df.emp_length.value_counts()
# Out:
# emp_length
# 10    8368
# 0     4329
# 2     4202
# 3     3947
# 4     3290
# 5     3157
# 1     3071
# 6     2133
# 7     1686
# 8     1408
# 9     1209
# Name: count, dtype: int64

# %%
features_df.revol_util
# Out:
# 0        83.70%
# 1         9.40%
# 2        98.50%
# 3           21%
# 5        28.30%
#           ...
# 39562    68.70%
# 39573       79%
# 39623    62.90%
# 39666    34.30%
# 39680    70.90%
# Name: revol_util, Length: 36800, dtype: object

# %%
features_df['revol_util'] = features_df.revol_util.apply(lambda x: round(float(x.split('%')[0]), 2))

# %%
features_df.isnull().sum().sort_values()
# Out:
# loan_amnt               0
# revol_util              0
# pub_rec                 0
# open_acc                0
# dti                     0
# addr_state              0
# purpose                 0
# loan_status             0
# issue_d                 0
# verification_status     0
# annual_inc              0
# home_ownership          0
# emp_length              0
# sub_grade               0
# grade                   0
# installment             0
# int_rate                0
# term                    0
# funded_amnt_inv         0
# funded_amnt             0
# total_acc               0
# pub_rec_bankruptcies    0
# dtype: int64

# %% [markdown]
# Now there are no null values in the dataset. The dataset can now enhanced with more features and corrected datatypes.

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36800 entries, 0 to 39680
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             36800 non-null  int64
#  1   funded_amnt           36800 non-null  int64
#  2   funded_amnt_inv       36800 non-null  float64
#  3   term                  36800 non-null  object
#  4   int_rate              36800 non-null  object
#  5   installment           36800 non-null  float64
#  6   grade                 36800 non-null  object
#  7   sub_grade             36800 non-null  object
#  8   emp_length            36800 non-null  object
#  9   home_ownership        36800 non-null  object
#  10  annual_inc            36800 non-null  float64
#  11  verification_status   36800 non-null  object
#  12  issue_d               36800 non-null  object
#  13  loan_status           36800 non-null  object
#  14  purpose               36800 non-null  object
#  15  addr_state            36800 non-null  object
#  16  dti                   36800 non-null  float64
#  17  open_acc              36800 non-null  int64
#  18  pub_rec               36800 non-null  int64
#  19  revol_util            36800 non-null  float64
#  20  total_acc             36800 non-null  int64
#  21  pub_rec_bankruptcies  36800 non-null  float64
# dtypes: float64(6), int64(5), object(11)
# memory usage: 6.5+ MB

# %%
features_df.funded_amnt_inv = features_df.funded_amnt_inv.astype(int)

# %%
features_df.term = features_df.term.apply(lambda x: x.split()[0]).astype(int)

# %%
features_df.term.unique()
# Out:
# array([36, 60])

# %%
features_df
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment  \
# 0           5000         5000             4975    36   10.65%       162.87
# 1           2500         2500             2500    60   15.27%        59.83
# 2           2400         2400             2400    36   15.96%        84.33
# 3          10000        10000            10000    36   13.49%       339.31
# 5           5000         5000             5000    36    7.90%       156.46
# ...          ...          ...              ...   ...      ...          ...
# 39562       4800         4800             1100    36   10.28%       155.52
# 39573       7000         7000             1000    36   10.59%       227.82
# 39623       9000         9000              700    36   12.49%       301.04
# 39666      15450        15450              600    36   11.22%       507.46
# 39680       3000         3000              525    36   11.86%        99.44
#
#       grade sub_grade emp_length home_ownership  ...  issue_d  loan_status  \
# 0         B        B2         10           RENT  ...   Dec-11   Fully Paid
# 1         C        C4          0           RENT  ...   Dec-11  Charged Off
# 2         C        C5         10           RENT  ...   Dec-11   Fully Paid
# 3         C        C1         10           RENT  ...   Dec-11   Fully Paid
# 5         A        A4          3           RENT  ...   Dec-11   Fully Paid
# ...     ...       ...        ...            ...  ...      ...          ...
# 39562     C        C1          1           RENT  ...   Nov-07   Fully Paid
# 39573     C        C2          3       MORTGAGE  ...   Nov-07   Fully Paid
# 39623     D        D3          8       MORTGAGE  ...   Oct-07  Charged Off
# 39666     C        C4          2       MORTGAGE  ...   Aug-07  Charged Off
# 39680     D        D1          2       MORTGAGE  ...   Aug-07   Fully Paid
#
#                   purpose addr_state    dti open_acc  pub_rec  revol_util  \
# 0             credit_card         AZ  27.65        3        0        83.7
# 1                     car         GA   1.00        3        0         9.4
# 2          small_business         IL   8.72        2        0        98.5
# 3                   other         CA  20.00       10        0        21.0
# 5                 wedding         AZ  11.20        9        0        28.3
# ...                   ...        ...    ...      ...      ...         ...
# 39562  debt_consolidation         VA   7.51       11        1        68.7
# 39573  debt_consolidation         AZ   8.50        9        1        79.0
# 39623  debt_consolidation         MD   5.08        9        1        62.9
# 39666  debt_consolidation         VA  13.50       13        1        34.3
# 39680  debt_consolidation         IN   7.47        3        1        70.9
#
#        total_acc  pub_rec_bankruptcies
# 0              9                   0.0
# 1              4                   0.0
# 2             10                   0.0
# 3             37                   0.0
# 5             12                   0.0
# ...          ...                   ...
# 39562         12                   1.0
# 39573         21                   1.0
# 39623         37                   1.0
# 39666         29                   1.0
# 39680          6                   1.0
#
# [36800 rows x 22 columns]

# %%
features_df.int_rate = features_df.int_rate.apply(lambda x: x.replace('%', '')).astype(float)

# %%
features_df.int_rate.value_counts()
# Out:
# int_rate
# 10.99    891
# 11.49    766
# 7.51     756
# 13.49    736
# 7.88     701
#         ...
# 16.96      1
# 17.46      1
# 16.20      1
# 18.72      1
# 11.22      1
# Name: count, Length: 336, dtype: int64

# %%
features_df
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 0           5000         5000             4975    36     10.65       162.87
# 1           2500         2500             2500    60     15.27        59.83
# 2           2400         2400             2400    36     15.96        84.33
# 3          10000        10000            10000    36     13.49       339.31
# 5           5000         5000             5000    36      7.90       156.46
# ...          ...          ...              ...   ...       ...          ...
# 39562       4800         4800             1100    36     10.28       155.52
# 39573       7000         7000             1000    36     10.59       227.82
# 39623       9000         9000              700    36     12.49       301.04
# 39666      15450        15450              600    36     11.22       507.46
# 39680       3000         3000              525    36     11.86        99.44
#
#       grade sub_grade emp_length home_ownership  ...  issue_d  loan_status  \
# 0         B        B2         10           RENT  ...   Dec-11   Fully Paid
# 1         C        C4          0           RENT  ...   Dec-11  Charged Off
# 2         C        C5         10           RENT  ...   Dec-11   Fully Paid
# 3         C        C1         10           RENT  ...   Dec-11   Fully Paid
# 5         A        A4          3           RENT  ...   Dec-11   Fully Paid
# ...     ...       ...        ...            ...  ...      ...          ...
# 39562     C        C1          1           RENT  ...   Nov-07   Fully Paid
# 39573     C        C2          3       MORTGAGE  ...   Nov-07   Fully Paid
# 39623     D        D3          8       MORTGAGE  ...   Oct-07  Charged Off
# 39666     C        C4          2       MORTGAGE  ...   Aug-07  Charged Off
# 39680     D        D1          2       MORTGAGE  ...   Aug-07   Fully Paid
#
#                   purpose addr_state    dti open_acc  pub_rec  revol_util  \
# 0             credit_card         AZ  27.65        3        0        83.7
# 1                     car         GA   1.00        3        0         9.4
# 2          small_business         IL   8.72        2        0        98.5
# 3                   other         CA  20.00       10        0        21.0
# 5                 wedding         AZ  11.20        9        0        28.3
# ...                   ...        ...    ...      ...      ...         ...
# 39562  debt_consolidation         VA   7.51       11        1        68.7
# 39573  debt_consolidation         AZ   8.50        9        1        79.0
# 39623  debt_consolidation         MD   5.08        9        1        62.9
# 39666  debt_consolidation         VA  13.50       13        1        34.3
# 39680  debt_consolidation         IN   7.47        3        1        70.9
#
#        total_acc  pub_rec_bankruptcies
# 0              9                   0.0
# 1              4                   0.0
# 2             10                   0.0
# 3             37                   0.0
# 5             12                   0.0
# ...          ...                   ...
# 39562         12                   1.0
# 39573         21                   1.0
# 39623         37                   1.0
# 39666         29                   1.0
# 39680          6                   1.0
#
# [36800 rows x 22 columns]

# %%
features_df.pub_rec_bankruptcies.value_counts()
# Out:
# pub_rec_bankruptcies
# 0.0    35266
# 1.0     1529
# 2.0        5
# Name: count, dtype: int64

# %%
features_df.pub_rec_bankruptcies = features_df.pub_rec_bankruptcies.astype(int)

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36800 entries, 0 to 39680
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             36800 non-null  int64
#  1   funded_amnt           36800 non-null  int64
#  2   funded_amnt_inv       36800 non-null  int32
#  3   term                  36800 non-null  int32
#  4   int_rate              36800 non-null  float64
#  5   installment           36800 non-null  float64
#  6   grade                 36800 non-null  object
#  7   sub_grade             36800 non-null  object
#  8   emp_length            36800 non-null  object
#  9   home_ownership        36800 non-null  object
#  10  annual_inc            36800 non-null  float64
#  11  verification_status   36800 non-null  object
#  12  issue_d               36800 non-null  object
#  13  loan_status           36800 non-null  object
#  14  purpose               36800 non-null  object
#  15  addr_state            36800 non-null  object
#  16  dti                   36800 non-null  float64
#  17  open_acc              36800 non-null  int64
#  18  pub_rec               36800 non-null  int64
#  19  revol_util            36800 non-null  float64
#  20  total_acc             36800 non-null  int64
#  21  pub_rec_bankruptcies  36800 non-null  int32
# dtypes: float64(5), int32(3), int64(5), object(9)
# memory usage: 6.0+ MB

# %%
# features_df[['grade', 'sub_grade']] = features_df[['grade', 'sub_grade']].astype(str)
features_df.emp_length = features_df.emp_length.astype(int)

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36800 entries, 0 to 39680
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             36800 non-null  int64
#  1   funded_amnt           36800 non-null  int64
#  2   funded_amnt_inv       36800 non-null  int32
#  3   term                  36800 non-null  int32
#  4   int_rate              36800 non-null  float64
#  5   installment           36800 non-null  float64
#  6   grade                 36800 non-null  object
#  7   sub_grade             36800 non-null  object
#  8   emp_length            36800 non-null  int32
#  9   home_ownership        36800 non-null  object
#  10  annual_inc            36800 non-null  float64
#  11  verification_status   36800 non-null  object
#  12  issue_d               36800 non-null  object
#  13  loan_status           36800 non-null  object
#  14  purpose               36800 non-null  object
#  15  addr_state            36800 non-null  object
#  16  dti                   36800 non-null  float64
#  17  open_acc              36800 non-null  int64
#  18  pub_rec               36800 non-null  int64
#  19  revol_util            36800 non-null  float64
#  20  total_acc             36800 non-null  int64
#  21  pub_rec_bankruptcies  36800 non-null  int32
# dtypes: float64(5), int32(4), int64(5), object(8)
# memory usage: 5.9+ MB

# %%
features_df['issue_date'] = pd.to_datetime(features_df.issue_d, format = '%b-%y')

# %%
features_df[['issue_date', 'issue_d']]
# Out:
#       issue_date issue_d
# 0     2011-12-01  Dec-11
# 1     2011-12-01  Dec-11
# 2     2011-12-01  Dec-11
# 3     2011-12-01  Dec-11
# 5     2011-12-01  Dec-11
# ...          ...     ...
# 39562 2007-11-01  Nov-07
# 39573 2007-11-01  Nov-07
# 39623 2007-10-01  Oct-07
# 39666 2007-08-01  Aug-07
# 39680 2007-08-01  Aug-07
#
# [36800 rows x 2 columns]

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36800 entries, 0 to 39680
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             36800 non-null  int64
#  1   funded_amnt           36800 non-null  int64
#  2   funded_amnt_inv       36800 non-null  int32
#  3   term                  36800 non-null  int32
#  4   int_rate              36800 non-null  float64
#  5   installment           36800 non-null  float64
#  6   grade                 36800 non-null  object
#  7   sub_grade             36800 non-null  object
#  8   emp_length            36800 non-null  int32
#  9   home_ownership        36800 non-null  object
#  10  annual_inc            36800 non-null  float64
#  11  verification_status   36800 non-null  object
#  12  issue_d               36800 non-null  object
#  13  loan_status           36800 non-null  object
#  14  purpose               36800 non-null  object
#  15  addr_state            36800 non-null  object
#  16  dti                   36800 non-null  float64
#  17  open_acc              36800 non-null  int64
#  18  pub_rec               36800 non-null  int64
#  19  revol_util            36800 non-null  float64
#  20  total_acc             36800 non-null  int64
#  21  pub_rec_bankruptcies  36800 non-null  int32
#  22  issue_date            36800 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int32(4), int64(5), object(8)
# memory usage: 6.2+ MB

# %%
features_df.pub_rec.value_counts()
# Out:
# pub_rec
# 0    34871
# 1     1875
# 2       45
# 3        7
# 4        2
# Name: count, dtype: int64

# %% [markdown]
# The data has been cleaned up, few derived columns can be created.

# %%
features_df[['loan_amnt', 'funded_amnt', 'funded_amnt_inv']].plot.box()
# Out:
# <Axes: >

# %%
features_df[features_df['loan_amnt']>30000]['loan_status'].value_counts()/features_df[features_df['loan_amnt']>30000]['loan_status'].count()
# Out:
# loan_status
# Fully Paid     0.758333
# Charged Off    0.241667
# Name: count, dtype: float64

# %%
#Need to analyze if there is a coorelation between % of amount funded vs loan on the defaults
features_df[features_df['loan_amnt'] != features_df['funded_amnt'] ]
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 61         17500         8950             8925    60     17.27       223.74
# 66         12500         8925             8925    60     17.27       223.11
# 70         20975        13575            13550    60     17.58       341.63
# 77          7250         7200             7175    60     21.67       197.51
# 80         35000        22075            22050    60     17.27       551.84
# ...          ...          ...              ...   ...       ...          ...
# 38886      25000        18175            14903    36     10.08       587.14
# 38889      12000         6500             4250    36     11.34       213.85
# 38890      25000        18825            14575    36     15.76       659.61
# 38893      20000         6875             3775    36     10.71       224.14
# 38897      23000         4325             1684    36     11.03       141.66
#
#       grade sub_grade  emp_length home_ownership  ...  loan_status  \
# 61        D        D3           6           RENT  ...   Fully Paid
# 66        D        D3           5           RENT  ...  Charged Off
# 70        D        D4           5       MORTGAGE  ...   Fully Paid
# 77        F        F3           0           RENT  ...   Fully Paid
# 80        D        D3           3       MORTGAGE  ...   Fully Paid
# ...     ...       ...         ...            ...  ...          ...
# 38886     B        B3           2       MORTGAGE  ...   Fully Paid
# 38889     C        C2          10            OWN  ...   Fully Paid
# 38890     F        F1           7       MORTGAGE  ...   Fully Paid
# 38893     B        B5           4       MORTGAGE  ...   Fully Paid
# 38897     C        C1           0       MORTGAGE  ...   Fully Paid
#
#                   purpose addr_state    dti open_acc pub_rec  revol_util  \
# 61         small_business         CA  19.47        5       0        58.9
# 66     debt_consolidation         MN  13.16        7       1        70.8
# 70            credit_card         GA  18.79       13       1        79.4
# 77     debt_consolidation         CA  24.82        9       1        91.2
# 80       home_improvement         NY   7.51       11       0        53.3
# ...                   ...        ...    ...      ...     ...         ...
# 38886      major_purchase         NJ   4.51        9       0        39.5
# 38889  debt_consolidation         FL  20.82       14       1        50.6
# 38890  debt_consolidation         CA  14.23        9       1        94.6
# 38893         credit_card         TX   9.66        3       0        90.2
# 38897               other         CA  15.07       11       0        88.7
#
#        total_acc  pub_rec_bankruptcies  issue_date
# 61             6                     0  2011-12-01
# 66            28                     1  2011-12-01
# 70            21                     1  2011-12-01
# 77            19                     1  2011-12-01
# 80            31                     0  2011-12-01
# ...          ...                   ...         ...
# 38886         39                     0  2008-04-01
# 38889         22                     1  2008-04-01
# 38890         30                     1  2008-04-01
# 38893         25                     0  2008-04-01
# 38897         30                     0  2008-04-01
#
# [1717 rows x 23 columns]

# %%
features_df[features_df['funded_amnt_inv'] != features_df['funded_amnt'] ]
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 0           5000         5000             4975    36     10.65       162.87
# 9           5375         5375             5350    60     12.69       121.45
# 20         20250        20250            19142    60     15.27       484.63
# 26         15000        15000             8725    36     14.27       514.64
# 51         25600        25600            25350    36      9.91       824.96
# ...          ...          ...              ...   ...       ...          ...
# 39562       4800         4800             1100    36     10.28       155.52
# 39573       7000         7000             1000    36     10.59       227.82
# 39623       9000         9000              700    36     12.49       301.04
# 39666      15450        15450              600    36     11.22       507.46
# 39680       3000         3000              525    36     11.86        99.44
#
#       grade sub_grade  emp_length home_ownership  ...  loan_status  \
# 0         B        B2          10           RENT  ...   Fully Paid
# 9         B        B5           0           RENT  ...  Charged Off
# 20        C        C4           3           RENT  ...   Fully Paid
# 26        C        C2           9           RENT  ...  Charged Off
# 51        B        B1           9           RENT  ...   Fully Paid
# ...     ...       ...         ...            ...  ...          ...
# 39562     C        C1           1           RENT  ...   Fully Paid
# 39573     C        C2           3       MORTGAGE  ...   Fully Paid
# 39623     D        D3           8       MORTGAGE  ...  Charged Off
# 39666     C        C4           2       MORTGAGE  ...  Charged Off
# 39680     D        D1           2       MORTGAGE  ...   Fully Paid
#
#                   purpose addr_state    dti open_acc pub_rec  revol_util  \
# 0             credit_card         AZ  27.65        3       0        83.7
# 9                   other         TX  18.08        2       0        36.5
# 20     debt_consolidation         TX  26.53        8       0        85.6
# 26     debt_consolidation         NY  15.22        7       0        57.6
# 51            credit_card         CA  15.71       11       0        62.0
# ...                   ...        ...    ...      ...     ...         ...
# 39562  debt_consolidation         VA   7.51       11       1        68.7
# 39573  debt_consolidation         AZ   8.50        9       1        79.0
# 39623  debt_consolidation         MD   5.08        9       1        62.9
# 39666  debt_consolidation         VA  13.50       13       1        34.3
# 39680  debt_consolidation         IN   7.47        3       1        70.9
#
#        total_acc  pub_rec_bankruptcies  issue_date
# 0              9                     0  2011-12-01
# 9              3                     0  2011-12-01
# 20            22                     0  2011-12-01
# 26            11                     0  2011-12-01
# 51            27                     0  2011-12-01
# ...          ...                   ...         ...
# 39562         12                     1  2007-11-01
# 39573         21                     1  2007-11-01
# 39623         37                     1  2007-10-01
# 39666         29                     1  2007-08-01
# 39680          6                     1  2007-08-01
#
# [18189 rows x 23 columns]

# %%
pd.qcut(features_df['int_rate'], q=4, precision =0, labels = ['Low', 'Moderate', 'High', 'Very High']).value_counts()
# Out:
# int_rate
# Low          9258
# High         9198
# Very High    9185
# Moderate     9159
# Name: count, dtype: int64

# %%
# features_df['int_rate'].plot.box()
# features_df['int_rate'].describe()
features_df['int_rate_group'] = pd.qcut(features_df['int_rate'], q=4, precision =0, labels = ['Low', 'Moderate', 'High', 'Very High'])

# %%
features_df['issue_date_month'] = features_df['issue_date'].dt.month

# %%
features_df['issue_date_year'] = features_df['issue_date'].dt.year

# %%
features_df['annual_inc_group'] = pd.qcut(features_df['annual_inc']/1000, q=4, precision =0, labels = ['3-41K', '41-60K', '60-83K', '83-6000K'])

# %%
features_df['dti_group'] = pd.qcut(features_df['dti'], q=4, precision =0, labels = ['Low', 'Moderate', 'High', 'Very High'])

# %%
features_df['open_acc_group'] = pd.qcut(features_df['open_acc'], q=4, precision =0, labels = ['Low', 'Moderate', 'High', 'Very High'])
features_df['total_acc_group'] = pd.qcut(features_df['total_acc'], q=4, precision =0, labels = ['Low', 'Moderate', 'High', 'Very High'])

# %%
features_df['revol_util_group'] = pd.qcut(features_df['revol_util'], q=4, precision =0, labels = ['Low', 'Moderate', 'High', 'Very High'])

# %%
# features_df[features_df.pub_rec_bankruptcies < features_df.pub_rec]
print(features_df.pub_rec.value_counts())
print(features_df.pub_rec_bankruptcies.value_counts())
# Out:
# pub_rec
# 0    34871
# 1     1875
# 2       45
# 3        7
# 4        2
# Name: count, dtype: int64
# pub_rec_bankruptcies
# 0    35266
# 1     1529
# 2        5
# Name: count, dtype: int64

# %%
features_df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'purpose', 'addr_state', 'dti', 'open_acc', 'pub_rec', 'revol_util',
#        'total_acc', 'pub_rec_bankruptcies', 'issue_date', 'int_rate_group',
#        'issue_date_month', 'issue_date_year', 'annual_inc_group', 'dti_group',
#        'open_acc_group', 'total_acc_group', 'revol_util_group'],
#       dtype='object')

# %%
column_names = {	
'loan_amnt'	:	'Loan Amount',
'funded_amnt':'Funded Loan Amount',
'installment':'Installment Amount',
'annual_inc':'Borrower Annual Income',
'purpose':'Purpose of Loan',
'total_acc':'Total Credit Accounts',
'issue_date_month':'Loan Funded Month',
'open_acc_group':'Open Credit Accounts - Group',
'funded_amnt_inv':'Funded Amount by Investor',
'grade':'Grade',
'verification_status':'Verification Status',
'addr_state':'Address State of Borrower',
'pub_rec_bankruptcies':'Public Record of Bankrupcies',
'issue_date_year':'Loan Funded Year',
'total_acc_group':'Total Credit Accounts - Group',
'term':'Loan Term - Months',
'sub_grade':'Sub-Grade',
'issue_d':'Loan Funded Date - Short',
'dti':'DTI',
'issue_date':'Loan Funded Date',
'annual_inc_group':'Borrower Annual Income - Group',
'revol_util_group':'Revolving Line Utilization - Group',
'int_rate':'Interest Rate',
'emp_length':'Employee Tenure',
'loan_status':'Loan Status',
'open_acc':'Open Line of Credit',
'int_rate_group':'Interest Rate - Group',
'dti_group':'DTI - Group',
'pub_rec':'Public Records',
'revol_util':'Revolving Line Utilization',
'home_ownership':'Home Ownership'
}

# %%
transformed_df = features_df.copy()

# %%
transformed_df.rename(columns = column_names, inplace = True)

# %%
transformed_df
# Out:
#        Loan Amount  Funded Loan Amount  Funded Amount by Investor  \
# 0             5000                5000                       4975
# 1             2500                2500                       2500
# 2             2400                2400                       2400
# 3            10000               10000                      10000
# 5             5000                5000                       5000
# ...            ...                 ...                        ...
# 39562         4800                4800                       1100
# 39573         7000                7000                       1000
# 39623         9000                9000                        700
# 39666        15450               15450                        600
# 39680         3000                3000                        525
#
#        Loan Term - Months  Interest Rate  Installment Amount Grade Sub-Grade  \
# 0                      36          10.65              162.87     B        B2
# 1                      60          15.27               59.83     C        C4
# 2                      36          15.96               84.33     C        C5
# 3                      36          13.49              339.31     C        C1
# 5                      36           7.90              156.46     A        A4
# ...                   ...            ...                 ...   ...       ...
# 39562                  36          10.28              155.52     C        C1
# 39573                  36          10.59              227.82     C        C2
# 39623                  36          12.49              301.04     D        D3
# 39666                  36          11.22              507.46     C        C4
# 39680                  36          11.86               99.44     D        D1
#
#        Employee Tenure Home Ownership  ...  Public Record of Bankrupcies  \
# 0                   10           RENT  ...                             0
# 1                    0           RENT  ...                             0
# 2                   10           RENT  ...                             0
# 3                   10           RENT  ...                             0
# 5                    3           RENT  ...                             0
# ...                ...            ...  ...                           ...
# 39562                1           RENT  ...                             1
# 39573                3       MORTGAGE  ...                             1
# 39623                8       MORTGAGE  ...                             1
# 39666                2       MORTGAGE  ...                             1
# 39680                2       MORTGAGE  ...                             1
#
#       Loan Funded Date Interest Rate - Group Loan Funded Month  \
# 0           2011-12-01              Moderate                12
# 1           2011-12-01             Very High                12
# 2           2011-12-01             Very High                12
# 3           2011-12-01                  High                12
# 5           2011-12-01                   Low                12
# ...                ...                   ...               ...
# 39562       2007-11-01              Moderate                11
# 39573       2007-11-01              Moderate                11
# 39623       2007-10-01                  High                10
# 39666       2007-08-01              Moderate                 8
# 39680       2007-08-01                  High                 8
#
#       Loan Funded Year Borrower Annual Income - Group  DTI - Group  \
# 0                 2011                          3-41K    Very High
# 1                 2011                          3-41K          Low
# 2                 2011                          3-41K     Moderate
# 3                 2011                         41-60K    Very High
# 5                 2011                          3-41K     Moderate
# ...                ...                            ...          ...
# 39562             2007                          3-41K          Low
# 39573             2007                         60-83K     Moderate
# 39623             2007                          3-41K          Low
# 39666             2007                          3-41K         High
# 39680             2007                          3-41K          Low
#
#        Open Credit Accounts - Group  Total Credit Accounts - Group  \
# 0                               Low                            Low
# 1                               Low                            Low
# 2                               Low                            Low
# 3                              High                      Very High
# 5                          Moderate                            Low
# ...                             ...                            ...
# 39562                          High                            Low
# 39573                      Moderate                           High
# 39623                      Moderate                      Very High
# 39666                     Very High                           High
# 39680                           Low                            Low
#
#        Revolving Line Utilization - Group
# 0                               Very High
# 1                                     Low
# 2                               Very High
# 3                                     Low
# 5                                Moderate
# ...                                   ...
# 39562                                High
# 39573                           Very High
# 39623                                High
# 39666                            Moderate
# 39680                                High
#
# [36800 rows x 31 columns]

# %%
transformed_df['Loan Status'].value_counts().plot.pie(autopct='%1.0f%%', 
                                                      explode = (0, 0.1), 
                                                      shadow =True
                                                      )
plt.title('Loan Distribution by Status')
plt.legend()
plt.ylabel('')
plt.show()

# %%
transformed_df['Loan Funded Year'].value_counts().sort_index().plot.bar()
plt.title('Loan Distribution by Year')
plt.ylabel('Count of Loans')
plt.show()

# %%
# transformed_df['Loan Funded Month'].value_counts().sort_index().plot.bar()
# plt.title('Loan Distribution by Year')
# plt.ylabel('Count of Loans')
# plt.show()

# figure, axes = plt.subplots(1,3)

# transformed_df['Loan Funded Year'].value_counts().sort_index().plot.bar(ax=axes[0])
# transformed_df['Loan Funded Month'].value_counts().sort_index().plot.bar(ax=axes[1])
# transformed_df['Loan Funded Month'].value_counts().sort_index().plot.bar(ax=axes[2])

# plt.show()

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

# Plot each metric on a different subplot
transformed_df['Loan Funded Month'].value_counts().sort_index().plot(kind='bar', ax=axs[0], color='#1f77b4', title='Interest Rate 2023')
transformed_df['Loan Funded Year'].value_counts().sort_index().plot(kind='bar', ax=axs[1], color='#ff7f0e', title='Interest Rate 2024')
transformed_df['Loan Status'].value_counts().sort_index().plot(kind='bar', ax=axs[2], color='#2ca02c', title='Loan Amount')

# Set labels
# for ax in axs:
#     ax.set_xlabel('Loan Type')
#     ax.set_ylabel('Value')
#     ax.set_xticklabels(transformed_df.index, rotation=0)

# Adjust layout
plt.tight_layout()
plt.show()
